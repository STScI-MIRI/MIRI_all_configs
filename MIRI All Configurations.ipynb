# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#READ-ME" data-toc-modified-id="READ-ME-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>READ ME</a></span></li><li><span><a href="#Imaging" data-toc-modified-id="Imaging-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Imaging</a></span><ul class="toc-item"><li><span><a href="#MIR_IMAGE" data-toc-modified-id="MIR_IMAGE-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>MIR_IMAGE</a></span></li><li><span><a href="#MIR_FLATIMAGE" data-toc-modified-id="MIR_FLATIMAGE-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>MIR_FLATIMAGE</a></span></li><li><span><a href="#MIR_FLATIMAGE-EXT" data-toc-modified-id="MIR_FLATIMAGE-EXT-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>MIR_FLATIMAGE-EXT</a></span></li></ul></li><li><span><a href="#LRS" data-toc-modified-id="LRS-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>LRS</a></span><ul class="toc-item"><li><span><a href="#MIR_LRS-FIXEDSLIT" data-toc-modified-id="MIR_LRS-FIXEDSLIT-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>MIR_LRS-FIXEDSLIT</a></span></li><li><span><a href="#MIR_LRS-SLITLESS" data-toc-modified-id="MIR_LRS-SLITLESS-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>MIR_LRS-SLITLESS</a></span></li></ul></li><li><span><a href="#MRS" data-toc-modified-id="MRS-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>MRS</a></span><ul class="toc-item"><li><span><a href="#MIR_MRS" data-toc-modified-id="MIR_MRS-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>MIR_MRS</a></span></li><li><span><a href="#MIR_FLATMRS" data-toc-modified-id="MIR_FLATMRS-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>MIR_FLATMRS</a></span></li><li><span><a href="#MIR_FLATMRS-EXT" data-toc-modified-id="MIR_FLATMRS-EXT-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>MIR_FLATMRS-EXT</a></span></li></ul></li><li><span><a href="#Coronography" data-toc-modified-id="Coronography-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Coronography</a></span><ul class="toc-item"><li><span><a href="#MIR_CORONCAL" data-toc-modified-id="MIR_CORONCAL-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>MIR_CORONCAL</a></span></li><li><span><a href="#MIR_LYOT" data-toc-modified-id="MIR_LYOT-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>MIR_LYOT</a></span></li><li><span><a href="#MIR_4QPM" data-toc-modified-id="MIR_4QPM-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>MIR_4QPM</a></span></li></ul></li><li><span><a href="#Target-Acquisition" data-toc-modified-id="Target-Acquisition-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Target Acquisition</a></span><ul class="toc-item"><li><span><a href="#MIR_TACQ" data-toc-modified-id="MIR_TACQ-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>MIR_TACQ</a></span></li><li><span><a href="#MIR_TACONFIRM" data-toc-modified-id="MIR_TACONFIRM-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>MIR_TACONFIRM</a></span></li></ul></li><li><span><a href="#Darks" data-toc-modified-id="Darks-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Darks</a></span><ul class="toc-item"><li><span><a href="#MIR_DARKIMG" data-toc-modified-id="MIR_DARKIMG-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>MIR_DARKIMG</a></span></li><li><span><a href="#MIR_DARKMRS" data-toc-modified-id="MIR_DARKMRS-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>MIR_DARKMRS</a></span></li></ul></li><li><span><a href="#print-to-file" data-toc-modified-id="print-to-file-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>print to file</a></span></li><li><span><a href="#Check-CRDS" data-toc-modified-id="Check-CRDS-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Check CRDS</a></span></li></ul></div>

# %% [markdown]
# # READ ME
#
# The intent of this notebook is to generate a list of every possible configuration of MIRI observations, and check each configuration in CRDS for a reference file. Possible configurations are informed by https://innerspace.stsci.edu/pages/viewpage.action?spaceKey=JWST&title=MIRI+Allowed+Configurations
#
# DISCLAIMER: This notebook is NOT intended for frequent use and is therefore not designed to be abstract or generalized. It is also not intended to be updated regularly. Should its use be required beyond the original design it will need to be re-evaluated for corrections to each MIRI configuration.

# %%
import pandas as pd
df = pd.DataFrame(columns=['Exposure Type', 
                           'Readout Mode',
                           'Filter',
                           'Band',
                           'Channel',
                           'Detector',
                           'SubArray'])
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Imaging

# %% [markdown]
# ## MIR_IMAGE

# %%
exp_type = ['MIR_IMAGE']
mode = ['FAST', 'SLOW', 'FASTGRPAVG']
filt = ['F560W', 
        'F770W', 
        'F1000W',
        'F1130W', 
        'F1280W', 
        'F1500W',
        'F1800W', 
        'F2100W', 
        'F2550W',
        'FLENS',
        'OPAQUE',
        'FND',
        'F1065C',
        'F1140C',
        'F1550C',
        'F2300C',
        'P750L']
sub = ['FULL',
       'BRIGHTSKY',
       'SUB256',
       'SUB128',
       'SUB64',
       'SLITLESSPRISM']

# %%
# MIR_IMAGE
for m in mode:
    for f in filt:
        for s in sub:
            if m == 'SLOW' and s != 'FULL':
                pass
            else:
                temp = {'Exposure Type':'MIR_IMAGE',
                        'Readout Mode':m, 
                        'Filter':f, 
                        'SubArray':s,
                        'Detector': 'MIRIMAGE'}
                df = df.append(temp, ignore_index=True)

# %% [markdown]
# ## MIR_FLATIMAGE

# %%
exp_type = ['MIR_FLATIMAGE']
mode = ['FAST', 'SLOW']
filt = ['F560W', 
        'F770W', 
        'F1000W',
        'F1130W', 
        'F1280W', 
        'F1500W',
        'F1800W', 
        'F2100W', 
        'F2550W',
        'F2550WR', 
        'FLENS',
        'OPAQUE',
        'FND',
        'F1065C',
        'F1140C',
        'F1550C',
        'F2300C',
        'P750L']
sub = ['FULL',
       'BRIGHTSKY',
       'SUB256',
       'SUB128',
       'SUB64',
       'SLITLESSPRISM',
       'MASK1065',
       'MASK1140',
       'MASK1550',
       'MASKLYOT']

# %%
# MIR_FLATIMAGE
for m in mode:
    for f in filt:
        for s in sub:
            if m == 'SLOW' and s != 'FULL':
                pass
            else:
                temp = {'Exposure Type':'MIR_FLATIMAGE',
                        'Readout Mode':m, 
                        'Filter':f, 
                        'SubArray':s,
                       'Detector': 'MIRIMAGE'}
                df = df.append(temp, ignore_index=True)

# %% [markdown]
# ## MIR_FLATIMAGE-EXT

# %%
exp_type = ['MIR_FLATIMAGE-EXT']
mode = ['FAST', 'SLOW']
filt = ['F560W', 
        'F770W', 
        'F1000W',
        'F1130W', 
        'F1280W', 
        'F1500W',
        'F1800W', 
        'F2100W', 
        'F2550W',
        'F2550WR', 
        'FLENS',
        'OPAQUE',
        'FND',
        'F1065C',
        'F1140C',
        'F1550C',
        'F2300C',
        'P750L']
sub = ['FULL',
       'BRIGHTSKY',
       'SUB256',
       'SUB128',
       'SUB64',
       'SLITLESSPRISM',
       'MASK1065',
       'MASK1140',
       'MASK1550',
       'MASKLYOT']

# %%
# 'MIR_FLATIMAGE-EXT'
for m in mode:
    for f in filt:
        for s in sub:
            if m == 'SLOW' and s != 'FULL':
                pass
            else:
                temp = {'Exposure Type':'MIR_FLATIMAGE-EXT',
                        'Readout Mode':m, 
                        'Filter':f, 
                        'SubArray':s,
                       'Detector': 'MIRIMAGE'}
                df = df.append(temp, ignore_index=True)

# %% [markdown]
# # LRS

# %% [markdown]
# ## MIR_LRS-FIXEDSLIT

# %%
exp_type = ['MIR_LRS-FIXEDSLIT']
mode = ['FAST', 'SLOW', 'FASTGRPAVG']
filt = ['P750L']
sub = ['FULL']

for m in mode:
    for f in filt:
        for s in sub:
            temp = {'Exposure Type':'MIR_LRS-FIXEDSLIT',
                    'Readout Mode':m, 
                    'Filter':f, 
                    'SubArray':s,
                   'Detector': 'MIRIMAGE'}
            df = df.append(temp, ignore_index=True)

# %% [markdown]
# ## MIR_LRS-SLITLESS

# %%
exp_type = ['MIR_LRS-SLITLESS']
mode = ['FAST', 'FASTGRPAVG']
filt = ['P750L']
sub = ['SLITLESSPRISM']

for m in mode:
    for f in filt:
        for s in sub:
            temp = {'Exposure Type':'MIR_LRS-SLITLESS',
                    'Readout Mode':m, 
                    'Filter':f, 
                    'SubArray':s,
                   'Detector': 'MIRIMAGE'}
            df = df.append(temp, ignore_index=True)

# %% [markdown]
# # MRS

# %% [markdown]
# ## MIR_MRS

# %%
exp_type = ['MIR_MRS']
mode = ['FAST', 'SLOW', 'FASTGRPAVG']
band = ['SHORT', 'SHORT-MEDIUM', 'SHORT-LONG', 
        'MEDIUM-SHORT', 'MEDIUM', 'MEDIUM-LONG', 
        'LONG-SHORT', 'LONG-MEDIUM', 'LONG']
sub = ['FULL']
ch = ['12', '34']
#det = ['MIRIFUSHORT', 'MIRIFULONG']

for m in mode:
    for b in band:
        for c in ch:
            if c == '12':
                det = 'MIRIFUSHORT'
            else:
                det = 'MIRIFULONG'
            for s in sub:
                temp = {'Exposure Type':'MIR_MRS',
                        'Readout Mode':m, 
                        'Band':b, 
                        'Channel':c,
                        'Detector':det,
                        'SubArray':s}
                df = df.append(temp, ignore_index=True)

# %% [markdown]
# ## MIR_FLATMRS

# %%
exp_type = ['MIR_FLATMRS']
mode = ['FAST', 'SLOW']
band = ['SHORT', 'SHORT-MEDIUM', 'SHORT-LONG', 
        'MEDIUM-SHORT', 'MEDIUM', 'MEDIUM-LONG', 
        'LONG-SHORT', 'LONG-MEDIUM', 'LONG']
sub = ['FULL']
ch = ['12', '34']
#det = ['MIRIFUSHORT', 'MIRIFULONG']

for m in mode:
    for b in band:
        for c in ch:
            if c == '12':
                det = 'MIRIFUSHORT'
            else:
                det = 'MIRIFULONG'
            for s in sub:
                temp = {'Exposure Type':'MIR_MRS',
                        'Readout Mode':m, 
                        'Band':b, 
                        'Channel':c,
                        'Detector':det,
                        'SubArray':s}
                df = df.append(temp, ignore_index=True)

# %% [markdown]
# ## MIR_FLATMRS-EXT

# %% [markdown]
# exp_type = ['MIR_FLATMRS-EXT']
# mode = ['FAST', 'SLOW', 'FASTGRPAVG']
# band = ['SHORT', 'SHORT-MEDIUM', 'SHORT-LONG',
#         'MEDIUM-SHORT', 'MEDIUM', 'MEDIUM-LONG',
#         'LONG-SHORT', 'LONG-MEDIUM', 'LONG']
# sub = ['FULL']
# ch = ['12', '34']
# #det = ['MIRIFUSHORT', 'MIRIFULONG']
#
# for m in mode:
#     for b in band:
#         for c in ch:
#             if c == '12':
#                 det = 'MIRIFUSHORT'
#             else:
#                 det = 'MIRIFULONG'
#             for s in sub:
#                 temp = {'Exposure Type':'MIR_MRS',
#                         'Readout Mode':m,
#                         'Band':b,
#                         'Channel':c,
#                         'Detector':det,
#                         'SubArray':s}
#                 df = df.append(temp, ignore_index=True)

# %% [markdown]
# # Coronography

# %% [markdown]
# ## MIR_CORONCAL

# %%
exp_type = ['MIR_CORONCAL']
mode = ['FAST']
filt = ['F560W',
       'F1000W',
       'F1500W',
       'FND']
sub = ['MASK1065',
        'MASK1140',
        'MASK1550',
        'MASKLYOT']

for m in mode:
    for s in sub:
        if s == 'MASK1065':
            filt.append('F1065C')
        elif s == 'MASK1140':
            filt.append('F1140C')
        elif s == 'MASK1550':
            filt.append('F1550C')
        elif s == 'MASKLYOT':
            filt.append('F2300C')
        for f in filt:
            temp = {'Exposure Type':'MIR_CORONCAL',
                    'Readout Mode':m, 
                    'Filter':f, 
                    'SubArray':s,
                   'Detector': 'MIRIMAGE'}
            
            df = df.append(temp, ignore_index=True)

# %% [markdown]
# ## MIR_LYOT

# %%
exp_type = ['MIR_LYOT']
mode = ['FAST', 'FASTGRPAVG']
filt = ['F2300C']
sub = ['MASKLYOT']

for m in mode:
    for f in filt:
        for s in sub:
            temp = {'Exposure Type':'MIR_LYOT',
                    'Readout Mode':m, 
                    'Filter':f, 
                    'SubArray':s,
                   'Detector': 'MIRIMAGE'}
            df = df.append(temp, ignore_index=True)

# %% [markdown]
# ## MIR_4QPM

# %%
exp_type = ['MIR_4QPM']
mode = ['FAST', 'FASTGRPAVG']
sub = ['MASK1065',
      'MASK1140',
      'MASK1550']

for m in mode:
    for s in sub:
        if s == 'MASK1065':
            f = 'F1065C'
        elif s == 'MASK1140':
            f = 'F1140C'
        elif s == 'MASK1550':
            f = 'F1550C'
        temp = {'Exposure Type':'MIR_4QPM',
                'Readout Mode':m, 
                'Filter':f, 
                'SubArray':s,
               'Detector': 'MIRIMAGE'}
        df = df.append(temp, ignore_index=True)

# %% [markdown]
# # Target Acquisition

# %% [markdown]
# ## MIR_TACQ

# %%
exp_type = ['MIR_TACQ']
mode = ['FAST',
        'FASTGRPAVG',
        'FASTGRPAVG8',
        'FASTGRPAVG16',
        'FASTGRPAVG32',
        'FASTGRPAVG64']
filt = ['F560W',
       'F1000W',
       'F1500W',
       'FND']
sub = ['FULL',
       'SLITLESSPRISM',
       'MASK1065',
       'MASK1140',
       'MASK1550',
       'MASKLYOT']

for m in mode:
    for f in filt:
        for s in sub:
            temp = {'Exposure Type':'MIR_TACQ',
                    'Readout Mode':m, 
                    'Filter':f, 
                    'SubArray':s,
                   'Detector': 'MIRIMAGE'}
            df = df.append(temp, ignore_index=True)

# %% [markdown]
# ## MIR_TACONFIRM

# %%
exp_type = ['MIR_TACONFIRM']
mode = ['FAST']
filt = ['F560W',
       'F1000W',
       'F1500W',
       'FND']
sub = ['FULL', 'SLITLESSPRISM']

for m in mode:
    for f in filt:
        for s in sub:
            temp = {'Exposure Type':'MIR_TACONFIRM',
                    'Readout Mode':m, 
                    'Filter':f, 
                    'SubArray':s,
                   'Detector': 'MIRIMAGE'}
            df = df.append(temp, ignore_index=True)

# %% [markdown]
# # Darks

# %% [markdown]
# ## MIR_DARKIMG

# %%
exp_type = ['MIR_DARKIMG']
mode = ['FAST', 'SLOW', 'FASTGRPAVG']
#filt = ['OPAQUE']
sub = ['FULL',
       'BRIGHTSKY',
       'SUB256',
       'SUB128',
       'SUB64',
       'SLITLESSPRISM',
       'MASK1065',
       'MASK1140',
       'MASK1550',
       'MASKLYOT']

for m in mode:
    #for f in filt:
    for s in sub:
        temp = {'Exposure Type':'MIR_DARKIMG',
                'Readout Mode':m, 
                'Filter':f, 
                'SubArray':s,
               'Detector': 'MIRIMAGE'}
        df = df.append(temp, ignore_index=True)

# %% [markdown]
# ## MIR_DARKMRS

# %%
exp_type = ['MIR_DARKMRS']
mode = ['FAST', 'SLOW', 'FASTGRPAVG']
#filt = ['ANY', 'OPAQUE']
sub = ['FULL']
det = ['MIRIFUSHORT', 'MIRIFULONG']

for m in mode:
    #for f in filt:
    for s in sub:
        for d in det:
            temp = {'Exposure Type':'MIR_DARKMRS',
                    'Readout Mode':m, 
                    'Filter':f, 
                    'SubArray':s,
                    'Detector':d}
            df = df.append(temp, ignore_index=True)

# %% [markdown]
# # print to file

# %%
df.to_csv('MIRI_all_configs.txt')

# %%
df
# Out:
#          Exposure Type  Readout Mode   Filter          Band Channel  \
# 0            MIR_IMAGE          FAST    F560W           NaN     NaN
# 1            MIR_IMAGE          FAST    F560W           NaN     NaN
# 2            MIR_IMAGE          FAST    F560W           NaN     NaN
# 3            MIR_IMAGE          FAST    F560W           NaN     NaN
# 4            MIR_IMAGE          FAST    F560W           NaN     NaN
# 5            MIR_IMAGE          FAST    F560W           NaN     NaN
# 6            MIR_IMAGE          FAST    F770W           NaN     NaN
# 7            MIR_IMAGE          FAST    F770W           NaN     NaN
# 8            MIR_IMAGE          FAST    F770W           NaN     NaN
# 9            MIR_IMAGE          FAST    F770W           NaN     NaN
# 10           MIR_IMAGE          FAST    F770W           NaN     NaN
# 11           MIR_IMAGE          FAST    F770W           NaN     NaN
# 12           MIR_IMAGE          FAST   F1000W           NaN     NaN
# 13           MIR_IMAGE          FAST   F1000W           NaN     NaN
# 14           MIR_IMAGE          FAST   F1000W           NaN     NaN
# 15           MIR_IMAGE          FAST   F1000W           NaN     NaN
# 16           MIR_IMAGE          FAST   F1000W           NaN     NaN
# 17           MIR_IMAGE          FAST   F1000W           NaN     NaN
# 18           MIR_IMAGE          FAST   F1130W           NaN     NaN
# 19           MIR_IMAGE          FAST   F1130W           NaN     NaN
# 20           MIR_IMAGE          FAST   F1130W           NaN     NaN
# 21           MIR_IMAGE          FAST   F1130W           NaN     NaN
# 22           MIR_IMAGE          FAST   F1130W           NaN     NaN
# 23           MIR_IMAGE          FAST   F1130W           NaN     NaN
# 24           MIR_IMAGE          FAST   F1280W           NaN     NaN
# 25           MIR_IMAGE          FAST   F1280W           NaN     NaN
# 26           MIR_IMAGE          FAST   F1280W           NaN     NaN
# 27           MIR_IMAGE          FAST   F1280W           NaN     NaN
# 28           MIR_IMAGE          FAST   F1280W           NaN     NaN
# 29           MIR_IMAGE          FAST   F1280W           NaN     NaN
# 30           MIR_IMAGE          FAST   F1500W           NaN     NaN
# 31           MIR_IMAGE          FAST   F1500W           NaN     NaN
# 32           MIR_IMAGE          FAST   F1500W           NaN     NaN
# 33           MIR_IMAGE          FAST   F1500W           NaN     NaN
# 34           MIR_IMAGE          FAST   F1500W           NaN     NaN
# 35           MIR_IMAGE          FAST   F1500W           NaN     NaN
# 36           MIR_IMAGE          FAST   F1800W           NaN     NaN
# 37           MIR_IMAGE          FAST   F1800W           NaN     NaN
# 38           MIR_IMAGE          FAST   F1800W           NaN     NaN
# 39           MIR_IMAGE          FAST   F1800W           NaN     NaN
# 40           MIR_IMAGE          FAST   F1800W           NaN     NaN
# 41           MIR_IMAGE          FAST   F1800W           NaN     NaN
# 42           MIR_IMAGE          FAST   F2100W           NaN     NaN
# 43           MIR_IMAGE          FAST   F2100W           NaN     NaN
# 44           MIR_IMAGE          FAST   F2100W           NaN     NaN
# 45           MIR_IMAGE          FAST   F2100W           NaN     NaN
# 46           MIR_IMAGE          FAST   F2100W           NaN     NaN
# 47           MIR_IMAGE          FAST   F2100W           NaN     NaN
# 48           MIR_IMAGE          FAST   F2550W           NaN     NaN
# 49           MIR_IMAGE          FAST   F2550W           NaN     NaN
# 50           MIR_IMAGE          FAST   F2550W           NaN     NaN
# 51           MIR_IMAGE          FAST   F2550W           NaN     NaN
# 52           MIR_IMAGE          FAST   F2550W           NaN     NaN
# 53           MIR_IMAGE          FAST   F2550W           NaN     NaN
# 54           MIR_IMAGE          FAST    FLENS           NaN     NaN
# 55           MIR_IMAGE          FAST    FLENS           NaN     NaN
# 56           MIR_IMAGE          FAST    FLENS           NaN     NaN
# 57           MIR_IMAGE          FAST    FLENS           NaN     NaN
# 58           MIR_IMAGE          FAST    FLENS           NaN     NaN
# 59           MIR_IMAGE          FAST    FLENS           NaN     NaN
# 60           MIR_IMAGE          FAST   OPAQUE           NaN     NaN
# 61           MIR_IMAGE          FAST   OPAQUE           NaN     NaN
# 62           MIR_IMAGE          FAST   OPAQUE           NaN     NaN
# 63           MIR_IMAGE          FAST   OPAQUE           NaN     NaN
# 64           MIR_IMAGE          FAST   OPAQUE           NaN     NaN
# 65           MIR_IMAGE          FAST   OPAQUE           NaN     NaN
# 66           MIR_IMAGE          FAST      FND           NaN     NaN
# 67           MIR_IMAGE          FAST      FND           NaN     NaN
# 68           MIR_IMAGE          FAST      FND           NaN     NaN
# 69           MIR_IMAGE          FAST      FND           NaN     NaN
# 70           MIR_IMAGE          FAST      FND           NaN     NaN
# 71           MIR_IMAGE          FAST      FND           NaN     NaN
# 72           MIR_IMAGE          FAST   F1065C           NaN     NaN
# 73           MIR_IMAGE          FAST   F1065C           NaN     NaN
# 74           MIR_IMAGE          FAST   F1065C           NaN     NaN
# 75           MIR_IMAGE          FAST   F1065C           NaN     NaN
# 76           MIR_IMAGE          FAST   F1065C           NaN     NaN
# 77           MIR_IMAGE          FAST   F1065C           NaN     NaN
# 78           MIR_IMAGE          FAST   F1140C           NaN     NaN
# 79           MIR_IMAGE          FAST   F1140C           NaN     NaN
# 80           MIR_IMAGE          FAST   F1140C           NaN     NaN
# 81           MIR_IMAGE          FAST   F1140C           NaN     NaN
# 82           MIR_IMAGE          FAST   F1140C           NaN     NaN
# 83           MIR_IMAGE          FAST   F1140C           NaN     NaN
# 84           MIR_IMAGE          FAST   F1550C           NaN     NaN
# 85           MIR_IMAGE          FAST   F1550C           NaN     NaN
# 86           MIR_IMAGE          FAST   F1550C           NaN     NaN
# 87           MIR_IMAGE          FAST   F1550C           NaN     NaN
# 88           MIR_IMAGE          FAST   F1550C           NaN     NaN
# 89           MIR_IMAGE          FAST   F1550C           NaN     NaN
# 90           MIR_IMAGE          FAST   F2300C           NaN     NaN
# 91           MIR_IMAGE          FAST   F2300C           NaN     NaN
# 92           MIR_IMAGE          FAST   F2300C           NaN     NaN
# 93           MIR_IMAGE          FAST   F2300C           NaN     NaN
# 94           MIR_IMAGE          FAST   F2300C           NaN     NaN
# 95           MIR_IMAGE          FAST   F2300C           NaN     NaN
# 96           MIR_IMAGE          FAST    P750L           NaN     NaN
# 97           MIR_IMAGE          FAST    P750L           NaN     NaN
# 98           MIR_IMAGE          FAST    P750L           NaN     NaN
# 99           MIR_IMAGE          FAST    P750L           NaN     NaN
# 100          MIR_IMAGE          FAST    P750L           NaN     NaN
# 101          MIR_IMAGE          FAST    P750L           NaN     NaN
# 102          MIR_IMAGE          SLOW    F560W           NaN     NaN
# 103          MIR_IMAGE          SLOW    F770W           NaN     NaN
# 104          MIR_IMAGE          SLOW   F1000W           NaN     NaN
# 105          MIR_IMAGE          SLOW   F1130W           NaN     NaN
# 106          MIR_IMAGE          SLOW   F1280W           NaN     NaN
# 107          MIR_IMAGE          SLOW   F1500W           NaN     NaN
# 108          MIR_IMAGE          SLOW   F1800W           NaN     NaN
# 109          MIR_IMAGE          SLOW   F2100W           NaN     NaN
# 110          MIR_IMAGE          SLOW   F2550W           NaN     NaN
# 111          MIR_IMAGE          SLOW    FLENS           NaN     NaN
# 112          MIR_IMAGE          SLOW   OPAQUE           NaN     NaN
# 113          MIR_IMAGE          SLOW      FND           NaN     NaN
# 114          MIR_IMAGE          SLOW   F1065C           NaN     NaN
# 115          MIR_IMAGE          SLOW   F1140C           NaN     NaN
# 116          MIR_IMAGE          SLOW   F1550C           NaN     NaN
# 117          MIR_IMAGE          SLOW   F2300C           NaN     NaN
# 118          MIR_IMAGE          SLOW    P750L           NaN     NaN
# 119          MIR_IMAGE    FASTGRPAVG    F560W           NaN     NaN
# 120          MIR_IMAGE    FASTGRPAVG    F560W           NaN     NaN
# 121          MIR_IMAGE    FASTGRPAVG    F560W           NaN     NaN
# 122          MIR_IMAGE    FASTGRPAVG    F560W           NaN     NaN
# 123          MIR_IMAGE    FASTGRPAVG    F560W           NaN     NaN
# 124          MIR_IMAGE    FASTGRPAVG    F560W           NaN     NaN
# 125          MIR_IMAGE    FASTGRPAVG    F770W           NaN     NaN
# 126          MIR_IMAGE    FASTGRPAVG    F770W           NaN     NaN
# 127          MIR_IMAGE    FASTGRPAVG    F770W           NaN     NaN
# 128          MIR_IMAGE    FASTGRPAVG    F770W           NaN     NaN
# 129          MIR_IMAGE    FASTGRPAVG    F770W           NaN     NaN
# 130          MIR_IMAGE    FASTGRPAVG    F770W           NaN     NaN
# 131          MIR_IMAGE    FASTGRPAVG   F1000W           NaN     NaN
# 132          MIR_IMAGE    FASTGRPAVG   F1000W           NaN     NaN
# 133          MIR_IMAGE    FASTGRPAVG   F1000W           NaN     NaN
# 134          MIR_IMAGE    FASTGRPAVG   F1000W           NaN     NaN
# 135          MIR_IMAGE    FASTGRPAVG   F1000W           NaN     NaN
# 136          MIR_IMAGE    FASTGRPAVG   F1000W           NaN     NaN
# 137          MIR_IMAGE    FASTGRPAVG   F1130W           NaN     NaN
# 138          MIR_IMAGE    FASTGRPAVG   F1130W           NaN     NaN
# 139          MIR_IMAGE    FASTGRPAVG   F1130W           NaN     NaN
# 140          MIR_IMAGE    FASTGRPAVG   F1130W           NaN     NaN
# 141          MIR_IMAGE    FASTGRPAVG   F1130W           NaN     NaN
# 142          MIR_IMAGE    FASTGRPAVG   F1130W           NaN     NaN
# 143          MIR_IMAGE    FASTGRPAVG   F1280W           NaN     NaN
# 144          MIR_IMAGE    FASTGRPAVG   F1280W           NaN     NaN
# 145          MIR_IMAGE    FASTGRPAVG   F1280W           NaN     NaN
# 146          MIR_IMAGE    FASTGRPAVG   F1280W           NaN     NaN
# 147          MIR_IMAGE    FASTGRPAVG   F1280W           NaN     NaN
# 148          MIR_IMAGE    FASTGRPAVG   F1280W           NaN     NaN
# 149          MIR_IMAGE    FASTGRPAVG   F1500W           NaN     NaN
# 150          MIR_IMAGE    FASTGRPAVG   F1500W           NaN     NaN
# 151          MIR_IMAGE    FASTGRPAVG   F1500W           NaN     NaN
# 152          MIR_IMAGE    FASTGRPAVG   F1500W           NaN     NaN
# 153          MIR_IMAGE    FASTGRPAVG   F1500W           NaN     NaN
# 154          MIR_IMAGE    FASTGRPAVG   F1500W           NaN     NaN
# 155          MIR_IMAGE    FASTGRPAVG   F1800W           NaN     NaN
# 156          MIR_IMAGE    FASTGRPAVG   F1800W           NaN     NaN
# 157          MIR_IMAGE    FASTGRPAVG   F1800W           NaN     NaN
# 158          MIR_IMAGE    FASTGRPAVG   F1800W           NaN     NaN
# 159          MIR_IMAGE    FASTGRPAVG   F1800W           NaN     NaN
# 160          MIR_IMAGE    FASTGRPAVG   F1800W           NaN     NaN
# 161          MIR_IMAGE    FASTGRPAVG   F2100W           NaN     NaN
# 162          MIR_IMAGE    FASTGRPAVG   F2100W           NaN     NaN
# 163          MIR_IMAGE    FASTGRPAVG   F2100W           NaN     NaN
# 164          MIR_IMAGE    FASTGRPAVG   F2100W           NaN     NaN
# 165          MIR_IMAGE    FASTGRPAVG   F2100W           NaN     NaN
# 166          MIR_IMAGE    FASTGRPAVG   F2100W           NaN     NaN
# 167          MIR_IMAGE    FASTGRPAVG   F2550W           NaN     NaN
# 168          MIR_IMAGE    FASTGRPAVG   F2550W           NaN     NaN
# 169          MIR_IMAGE    FASTGRPAVG   F2550W           NaN     NaN
# 170          MIR_IMAGE    FASTGRPAVG   F2550W           NaN     NaN
# 171          MIR_IMAGE    FASTGRPAVG   F2550W           NaN     NaN
# 172          MIR_IMAGE    FASTGRPAVG   F2550W           NaN     NaN
# 173          MIR_IMAGE    FASTGRPAVG    FLENS           NaN     NaN
# 174          MIR_IMAGE    FASTGRPAVG    FLENS           NaN     NaN
# 175          MIR_IMAGE    FASTGRPAVG    FLENS           NaN     NaN
# 176          MIR_IMAGE    FASTGRPAVG    FLENS           NaN     NaN
# 177          MIR_IMAGE    FASTGRPAVG    FLENS           NaN     NaN
# 178          MIR_IMAGE    FASTGRPAVG    FLENS           NaN     NaN
# 179          MIR_IMAGE    FASTGRPAVG   OPAQUE           NaN     NaN
# 180          MIR_IMAGE    FASTGRPAVG   OPAQUE           NaN     NaN
# 181          MIR_IMAGE    FASTGRPAVG   OPAQUE           NaN     NaN
# 182          MIR_IMAGE    FASTGRPAVG   OPAQUE           NaN     NaN
# 183          MIR_IMAGE    FASTGRPAVG   OPAQUE           NaN     NaN
# 184          MIR_IMAGE    FASTGRPAVG   OPAQUE           NaN     NaN
# 185          MIR_IMAGE    FASTGRPAVG      FND           NaN     NaN
# 186          MIR_IMAGE    FASTGRPAVG      FND           NaN     NaN
# 187          MIR_IMAGE    FASTGRPAVG      FND           NaN     NaN
# 188          MIR_IMAGE    FASTGRPAVG      FND           NaN     NaN
# 189          MIR_IMAGE    FASTGRPAVG      FND           NaN     NaN
# 190          MIR_IMAGE    FASTGRPAVG      FND           NaN     NaN
# 191          MIR_IMAGE    FASTGRPAVG   F1065C           NaN     NaN
# 192          MIR_IMAGE    FASTGRPAVG   F1065C           NaN     NaN
# 193          MIR_IMAGE    FASTGRPAVG   F1065C           NaN     NaN
# 194          MIR_IMAGE    FASTGRPAVG   F1065C           NaN     NaN
# 195          MIR_IMAGE    FASTGRPAVG   F1065C           NaN     NaN
# 196          MIR_IMAGE    FASTGRPAVG   F1065C           NaN     NaN
# 197          MIR_IMAGE    FASTGRPAVG   F1140C           NaN     NaN
# 198          MIR_IMAGE    FASTGRPAVG   F1140C           NaN     NaN
# 199          MIR_IMAGE    FASTGRPAVG   F1140C           NaN     NaN
# 200          MIR_IMAGE    FASTGRPAVG   F1140C           NaN     NaN
# 201          MIR_IMAGE    FASTGRPAVG   F1140C           NaN     NaN
# 202          MIR_IMAGE    FASTGRPAVG   F1140C           NaN     NaN
# 203          MIR_IMAGE    FASTGRPAVG   F1550C           NaN     NaN
# 204          MIR_IMAGE    FASTGRPAVG   F1550C           NaN     NaN
# 205          MIR_IMAGE    FASTGRPAVG   F1550C           NaN     NaN
# 206          MIR_IMAGE    FASTGRPAVG   F1550C           NaN     NaN
# 207          MIR_IMAGE    FASTGRPAVG   F1550C           NaN     NaN
# 208          MIR_IMAGE    FASTGRPAVG   F1550C           NaN     NaN
# 209          MIR_IMAGE    FASTGRPAVG   F2300C           NaN     NaN
# 210          MIR_IMAGE    FASTGRPAVG   F2300C           NaN     NaN
# 211          MIR_IMAGE    FASTGRPAVG   F2300C           NaN     NaN
# 212          MIR_IMAGE    FASTGRPAVG   F2300C           NaN     NaN
# 213          MIR_IMAGE    FASTGRPAVG   F2300C           NaN     NaN
# 214          MIR_IMAGE    FASTGRPAVG   F2300C           NaN     NaN
# 215          MIR_IMAGE    FASTGRPAVG    P750L           NaN     NaN
# 216          MIR_IMAGE    FASTGRPAVG    P750L           NaN     NaN
# 217          MIR_IMAGE    FASTGRPAVG    P750L           NaN     NaN
# 218          MIR_IMAGE    FASTGRPAVG    P750L           NaN     NaN
# 219          MIR_IMAGE    FASTGRPAVG    P750L           NaN     NaN
# 220          MIR_IMAGE    FASTGRPAVG    P750L           NaN     NaN
# 221      MIR_FLATIMAGE          FAST    F560W           NaN     NaN
# 222      MIR_FLATIMAGE          FAST    F560W           NaN     NaN
# 223      MIR_FLATIMAGE          FAST    F560W           NaN     NaN
# 224      MIR_FLATIMAGE          FAST    F560W           NaN     NaN
# 225      MIR_FLATIMAGE          FAST    F560W           NaN     NaN
# 226      MIR_FLATIMAGE          FAST    F560W           NaN     NaN
# 227      MIR_FLATIMAGE          FAST    F560W           NaN     NaN
# 228      MIR_FLATIMAGE          FAST    F560W           NaN     NaN
# 229      MIR_FLATIMAGE          FAST    F560W           NaN     NaN
# 230      MIR_FLATIMAGE          FAST    F560W           NaN     NaN
# 231      MIR_FLATIMAGE          FAST    F770W           NaN     NaN
# 232      MIR_FLATIMAGE          FAST    F770W           NaN     NaN
# 233      MIR_FLATIMAGE          FAST    F770W           NaN     NaN
# 234      MIR_FLATIMAGE          FAST    F770W           NaN     NaN
# 235      MIR_FLATIMAGE          FAST    F770W           NaN     NaN
# 236      MIR_FLATIMAGE          FAST    F770W           NaN     NaN
# 237      MIR_FLATIMAGE          FAST    F770W           NaN     NaN
# 238      MIR_FLATIMAGE          FAST    F770W           NaN     NaN
# 239      MIR_FLATIMAGE          FAST    F770W           NaN     NaN
# 240      MIR_FLATIMAGE          FAST    F770W           NaN     NaN
# 241      MIR_FLATIMAGE          FAST   F1000W           NaN     NaN
# 242      MIR_FLATIMAGE          FAST   F1000W           NaN     NaN
# 243      MIR_FLATIMAGE          FAST   F1000W           NaN     NaN
# 244      MIR_FLATIMAGE          FAST   F1000W           NaN     NaN
# 245      MIR_FLATIMAGE          FAST   F1000W           NaN     NaN
# 246      MIR_FLATIMAGE          FAST   F1000W           NaN     NaN
# 247      MIR_FLATIMAGE          FAST   F1000W           NaN     NaN
# 248      MIR_FLATIMAGE          FAST   F1000W           NaN     NaN
# 249      MIR_FLATIMAGE          FAST   F1000W           NaN     NaN
# 250      MIR_FLATIMAGE          FAST   F1000W           NaN     NaN
# 251      MIR_FLATIMAGE          FAST   F1130W           NaN     NaN
# 252      MIR_FLATIMAGE          FAST   F1130W           NaN     NaN
# 253      MIR_FLATIMAGE          FAST   F1130W           NaN     NaN
# 254      MIR_FLATIMAGE          FAST   F1130W           NaN     NaN
# 255      MIR_FLATIMAGE          FAST   F1130W           NaN     NaN
# 256      MIR_FLATIMAGE          FAST   F1130W           NaN     NaN
# 257      MIR_FLATIMAGE          FAST   F1130W           NaN     NaN
# 258      MIR_FLATIMAGE          FAST   F1130W           NaN     NaN
# 259      MIR_FLATIMAGE          FAST   F1130W           NaN     NaN
# 260      MIR_FLATIMAGE          FAST   F1130W           NaN     NaN
# 261      MIR_FLATIMAGE          FAST   F1280W           NaN     NaN
# 262      MIR_FLATIMAGE          FAST   F1280W           NaN     NaN
# 263      MIR_FLATIMAGE          FAST   F1280W           NaN     NaN
# 264      MIR_FLATIMAGE          FAST   F1280W           NaN     NaN
# 265      MIR_FLATIMAGE          FAST   F1280W           NaN     NaN
# 266      MIR_FLATIMAGE          FAST   F1280W           NaN     NaN
# 267      MIR_FLATIMAGE          FAST   F1280W           NaN     NaN
# 268      MIR_FLATIMAGE          FAST   F1280W           NaN     NaN
# 269      MIR_FLATIMAGE          FAST   F1280W           NaN     NaN
# 270      MIR_FLATIMAGE          FAST   F1280W           NaN     NaN
# 271      MIR_FLATIMAGE          FAST   F1500W           NaN     NaN
# 272      MIR_FLATIMAGE          FAST   F1500W           NaN     NaN
# 273      MIR_FLATIMAGE          FAST   F1500W           NaN     NaN
# 274      MIR_FLATIMAGE          FAST   F1500W           NaN     NaN
# 275      MIR_FLATIMAGE          FAST   F1500W           NaN     NaN
# 276      MIR_FLATIMAGE          FAST   F1500W           NaN     NaN
# 277      MIR_FLATIMAGE          FAST   F1500W           NaN     NaN
# 278      MIR_FLATIMAGE          FAST   F1500W           NaN     NaN
# 279      MIR_FLATIMAGE          FAST   F1500W           NaN     NaN
# 280      MIR_FLATIMAGE          FAST   F1500W           NaN     NaN
# 281      MIR_FLATIMAGE          FAST   F1800W           NaN     NaN
# 282      MIR_FLATIMAGE          FAST   F1800W           NaN     NaN
# 283      MIR_FLATIMAGE          FAST   F1800W           NaN     NaN
# 284      MIR_FLATIMAGE          FAST   F1800W           NaN     NaN
# 285      MIR_FLATIMAGE          FAST   F1800W           NaN     NaN
# 286      MIR_FLATIMAGE          FAST   F1800W           NaN     NaN
# 287      MIR_FLATIMAGE          FAST   F1800W           NaN     NaN
# 288      MIR_FLATIMAGE          FAST   F1800W           NaN     NaN
# 289      MIR_FLATIMAGE          FAST   F1800W           NaN     NaN
# 290      MIR_FLATIMAGE          FAST   F1800W           NaN     NaN
# 291      MIR_FLATIMAGE          FAST   F2100W           NaN     NaN
# 292      MIR_FLATIMAGE          FAST   F2100W           NaN     NaN
# 293      MIR_FLATIMAGE          FAST   F2100W           NaN     NaN
# 294      MIR_FLATIMAGE          FAST   F2100W           NaN     NaN
# 295      MIR_FLATIMAGE          FAST   F2100W           NaN     NaN
# 296      MIR_FLATIMAGE          FAST   F2100W           NaN     NaN
# 297      MIR_FLATIMAGE          FAST   F2100W           NaN     NaN
# 298      MIR_FLATIMAGE          FAST   F2100W           NaN     NaN
# 299      MIR_FLATIMAGE          FAST   F2100W           NaN     NaN
# 300      MIR_FLATIMAGE          FAST   F2100W           NaN     NaN
# 301      MIR_FLATIMAGE          FAST   F2550W           NaN     NaN
# 302      MIR_FLATIMAGE          FAST   F2550W           NaN     NaN
# 303      MIR_FLATIMAGE          FAST   F2550W           NaN     NaN
# 304      MIR_FLATIMAGE          FAST   F2550W           NaN     NaN
# 305      MIR_FLATIMAGE          FAST   F2550W           NaN     NaN
# 306      MIR_FLATIMAGE          FAST   F2550W           NaN     NaN
# 307      MIR_FLATIMAGE          FAST   F2550W           NaN     NaN
# 308      MIR_FLATIMAGE          FAST   F2550W           NaN     NaN
# 309      MIR_FLATIMAGE          FAST   F2550W           NaN     NaN
# 310      MIR_FLATIMAGE          FAST   F2550W           NaN     NaN
# 311      MIR_FLATIMAGE          FAST  F2550WR           NaN     NaN
# 312      MIR_FLATIMAGE          FAST  F2550WR           NaN     NaN
# 313      MIR_FLATIMAGE          FAST  F2550WR           NaN     NaN
# 314      MIR_FLATIMAGE          FAST  F2550WR           NaN     NaN
# 315      MIR_FLATIMAGE          FAST  F2550WR           NaN     NaN
# 316      MIR_FLATIMAGE          FAST  F2550WR           NaN     NaN
# 317      MIR_FLATIMAGE          FAST  F2550WR           NaN     NaN
# 318      MIR_FLATIMAGE          FAST  F2550WR           NaN     NaN
# 319      MIR_FLATIMAGE          FAST  F2550WR           NaN     NaN
# 320      MIR_FLATIMAGE          FAST  F2550WR           NaN     NaN
# 321      MIR_FLATIMAGE          FAST    FLENS           NaN     NaN
# 322      MIR_FLATIMAGE          FAST    FLENS           NaN     NaN
# 323      MIR_FLATIMAGE          FAST    FLENS           NaN     NaN
# 324      MIR_FLATIMAGE          FAST    FLENS           NaN     NaN
# 325      MIR_FLATIMAGE          FAST    FLENS           NaN     NaN
# 326      MIR_FLATIMAGE          FAST    FLENS           NaN     NaN
# 327      MIR_FLATIMAGE          FAST    FLENS           NaN     NaN
# 328      MIR_FLATIMAGE          FAST    FLENS           NaN     NaN
# 329      MIR_FLATIMAGE          FAST    FLENS           NaN     NaN
# 330      MIR_FLATIMAGE          FAST    FLENS           NaN     NaN
# 331      MIR_FLATIMAGE          FAST   OPAQUE           NaN     NaN
# 332      MIR_FLATIMAGE          FAST   OPAQUE           NaN     NaN
# 333      MIR_FLATIMAGE          FAST   OPAQUE           NaN     NaN
# 334      MIR_FLATIMAGE          FAST   OPAQUE           NaN     NaN
# 335      MIR_FLATIMAGE          FAST   OPAQUE           NaN     NaN
# 336      MIR_FLATIMAGE          FAST   OPAQUE           NaN     NaN
# 337      MIR_FLATIMAGE          FAST   OPAQUE           NaN     NaN
# 338      MIR_FLATIMAGE          FAST   OPAQUE           NaN     NaN
# 339      MIR_FLATIMAGE          FAST   OPAQUE           NaN     NaN
# 340      MIR_FLATIMAGE          FAST   OPAQUE           NaN     NaN
# 341      MIR_FLATIMAGE          FAST      FND           NaN     NaN
# 342      MIR_FLATIMAGE          FAST      FND           NaN     NaN
# 343      MIR_FLATIMAGE          FAST      FND           NaN     NaN
# 344      MIR_FLATIMAGE          FAST      FND           NaN     NaN
# 345      MIR_FLATIMAGE          FAST      FND           NaN     NaN
# 346      MIR_FLATIMAGE          FAST      FND           NaN     NaN
# 347      MIR_FLATIMAGE          FAST      FND           NaN     NaN
# 348      MIR_FLATIMAGE          FAST      FND           NaN     NaN
# 349      MIR_FLATIMAGE          FAST      FND           NaN     NaN
# 350      MIR_FLATIMAGE          FAST      FND           NaN     NaN
# 351      MIR_FLATIMAGE          FAST   F1065C           NaN     NaN
# 352      MIR_FLATIMAGE          FAST   F1065C           NaN     NaN
# 353      MIR_FLATIMAGE          FAST   F1065C           NaN     NaN
# 354      MIR_FLATIMAGE          FAST   F1065C           NaN     NaN
# 355      MIR_FLATIMAGE          FAST   F1065C           NaN     NaN
# 356      MIR_FLATIMAGE          FAST   F1065C           NaN     NaN
# 357      MIR_FLATIMAGE          FAST   F1065C           NaN     NaN
# 358      MIR_FLATIMAGE          FAST   F1065C           NaN     NaN
# 359      MIR_FLATIMAGE          FAST   F1065C           NaN     NaN
# 360      MIR_FLATIMAGE          FAST   F1065C           NaN     NaN
# 361      MIR_FLATIMAGE          FAST   F1140C           NaN     NaN
# 362      MIR_FLATIMAGE          FAST   F1140C           NaN     NaN
# 363      MIR_FLATIMAGE          FAST   F1140C           NaN     NaN
# 364      MIR_FLATIMAGE          FAST   F1140C           NaN     NaN
# 365      MIR_FLATIMAGE          FAST   F1140C           NaN     NaN
# 366      MIR_FLATIMAGE          FAST   F1140C           NaN     NaN
# 367      MIR_FLATIMAGE          FAST   F1140C           NaN     NaN
# 368      MIR_FLATIMAGE          FAST   F1140C           NaN     NaN
# 369      MIR_FLATIMAGE          FAST   F1140C           NaN     NaN
# 370      MIR_FLATIMAGE          FAST   F1140C           NaN     NaN
# 371      MIR_FLATIMAGE          FAST   F1550C           NaN     NaN
# 372      MIR_FLATIMAGE          FAST   F1550C           NaN     NaN
# 373      MIR_FLATIMAGE          FAST   F1550C           NaN     NaN
# 374      MIR_FLATIMAGE          FAST   F1550C           NaN     NaN
# 375      MIR_FLATIMAGE          FAST   F1550C           NaN     NaN
# 376      MIR_FLATIMAGE          FAST   F1550C           NaN     NaN
# 377      MIR_FLATIMAGE          FAST   F1550C           NaN     NaN
# 378      MIR_FLATIMAGE          FAST   F1550C           NaN     NaN
# 379      MIR_FLATIMAGE          FAST   F1550C           NaN     NaN
# 380      MIR_FLATIMAGE          FAST   F1550C           NaN     NaN
# 381      MIR_FLATIMAGE          FAST   F2300C           NaN     NaN
# 382      MIR_FLATIMAGE          FAST   F2300C           NaN     NaN
# 383      MIR_FLATIMAGE          FAST   F2300C           NaN     NaN
# 384      MIR_FLATIMAGE          FAST   F2300C           NaN     NaN
# 385      MIR_FLATIMAGE          FAST   F2300C           NaN     NaN
# 386      MIR_FLATIMAGE          FAST   F2300C           NaN     NaN
# 387      MIR_FLATIMAGE          FAST   F2300C           NaN     NaN
# 388      MIR_FLATIMAGE          FAST   F2300C           NaN     NaN
# 389      MIR_FLATIMAGE          FAST   F2300C           NaN     NaN
# 390      MIR_FLATIMAGE          FAST   F2300C           NaN     NaN
# 391      MIR_FLATIMAGE          FAST    P750L           NaN     NaN
# 392      MIR_FLATIMAGE          FAST    P750L           NaN     NaN
# 393      MIR_FLATIMAGE          FAST    P750L           NaN     NaN
# 394      MIR_FLATIMAGE          FAST    P750L           NaN     NaN
# 395      MIR_FLATIMAGE          FAST    P750L           NaN     NaN
# 396      MIR_FLATIMAGE          FAST    P750L           NaN     NaN
# 397      MIR_FLATIMAGE          FAST    P750L           NaN     NaN
# 398      MIR_FLATIMAGE          FAST    P750L           NaN     NaN
# 399      MIR_FLATIMAGE          FAST    P750L           NaN     NaN
# 400      MIR_FLATIMAGE          FAST    P750L           NaN     NaN
# 401      MIR_FLATIMAGE          SLOW    F560W           NaN     NaN
# 402      MIR_FLATIMAGE          SLOW    F770W           NaN     NaN
# 403      MIR_FLATIMAGE          SLOW   F1000W           NaN     NaN
# 404      MIR_FLATIMAGE          SLOW   F1130W           NaN     NaN
# 405      MIR_FLATIMAGE          SLOW   F1280W           NaN     NaN
# 406      MIR_FLATIMAGE          SLOW   F1500W           NaN     NaN
# 407      MIR_FLATIMAGE          SLOW   F1800W           NaN     NaN
# 408      MIR_FLATIMAGE          SLOW   F2100W           NaN     NaN
# 409      MIR_FLATIMAGE          SLOW   F2550W           NaN     NaN
# 410      MIR_FLATIMAGE          SLOW  F2550WR           NaN     NaN
# 411      MIR_FLATIMAGE          SLOW    FLENS           NaN     NaN
# 412      MIR_FLATIMAGE          SLOW   OPAQUE           NaN     NaN
# 413      MIR_FLATIMAGE          SLOW      FND           NaN     NaN
# 414      MIR_FLATIMAGE          SLOW   F1065C           NaN     NaN
# 415      MIR_FLATIMAGE          SLOW   F1140C           NaN     NaN
# 416      MIR_FLATIMAGE          SLOW   F1550C           NaN     NaN
# 417      MIR_FLATIMAGE          SLOW   F2300C           NaN     NaN
# 418      MIR_FLATIMAGE          SLOW    P750L           NaN     NaN
# 419  MIR_FLATIMAGE-EXT          FAST    F560W           NaN     NaN
# 420  MIR_FLATIMAGE-EXT          FAST    F560W           NaN     NaN
# 421  MIR_FLATIMAGE-EXT          FAST    F560W           NaN     NaN
# 422  MIR_FLATIMAGE-EXT          FAST    F560W           NaN     NaN
# 423  MIR_FLATIMAGE-EXT          FAST    F560W           NaN     NaN
# 424  MIR_FLATIMAGE-EXT          FAST    F560W           NaN     NaN
# 425  MIR_FLATIMAGE-EXT          FAST    F560W           NaN     NaN
# 426  MIR_FLATIMAGE-EXT          FAST    F560W           NaN     NaN
# 427  MIR_FLATIMAGE-EXT          FAST    F560W           NaN     NaN
# 428  MIR_FLATIMAGE-EXT          FAST    F560W           NaN     NaN
# 429  MIR_FLATIMAGE-EXT          FAST    F770W           NaN     NaN
# 430  MIR_FLATIMAGE-EXT          FAST    F770W           NaN     NaN
# 431  MIR_FLATIMAGE-EXT          FAST    F770W           NaN     NaN
# 432  MIR_FLATIMAGE-EXT          FAST    F770W           NaN     NaN
# 433  MIR_FLATIMAGE-EXT          FAST    F770W           NaN     NaN
# 434  MIR_FLATIMAGE-EXT          FAST    F770W           NaN     NaN
# 435  MIR_FLATIMAGE-EXT          FAST    F770W           NaN     NaN
# 436  MIR_FLATIMAGE-EXT          FAST    F770W           NaN     NaN
# 437  MIR_FLATIMAGE-EXT          FAST    F770W           NaN     NaN
# 438  MIR_FLATIMAGE-EXT          FAST    F770W           NaN     NaN
# 439  MIR_FLATIMAGE-EXT          FAST   F1000W           NaN     NaN
# 440  MIR_FLATIMAGE-EXT          FAST   F1000W           NaN     NaN
# 441  MIR_FLATIMAGE-EXT          FAST   F1000W           NaN     NaN
# 442  MIR_FLATIMAGE-EXT          FAST   F1000W           NaN     NaN
# 443  MIR_FLATIMAGE-EXT          FAST   F1000W           NaN     NaN
# 444  MIR_FLATIMAGE-EXT          FAST   F1000W           NaN     NaN
# 445  MIR_FLATIMAGE-EXT          FAST   F1000W           NaN     NaN
# 446  MIR_FLATIMAGE-EXT          FAST   F1000W           NaN     NaN
# 447  MIR_FLATIMAGE-EXT          FAST   F1000W           NaN     NaN
# 448  MIR_FLATIMAGE-EXT          FAST   F1000W           NaN     NaN
# 449  MIR_FLATIMAGE-EXT          FAST   F1130W           NaN     NaN
# 450  MIR_FLATIMAGE-EXT          FAST   F1130W           NaN     NaN
# 451  MIR_FLATIMAGE-EXT          FAST   F1130W           NaN     NaN
# 452  MIR_FLATIMAGE-EXT          FAST   F1130W           NaN     NaN
# 453  MIR_FLATIMAGE-EXT          FAST   F1130W           NaN     NaN
# 454  MIR_FLATIMAGE-EXT          FAST   F1130W           NaN     NaN
# 455  MIR_FLATIMAGE-EXT          FAST   F1130W           NaN     NaN
# 456  MIR_FLATIMAGE-EXT          FAST   F1130W           NaN     NaN
# 457  MIR_FLATIMAGE-EXT          FAST   F1130W           NaN     NaN
# 458  MIR_FLATIMAGE-EXT          FAST   F1130W           NaN     NaN
# 459  MIR_FLATIMAGE-EXT          FAST   F1280W           NaN     NaN
# 460  MIR_FLATIMAGE-EXT          FAST   F1280W           NaN     NaN
# 461  MIR_FLATIMAGE-EXT          FAST   F1280W           NaN     NaN
# 462  MIR_FLATIMAGE-EXT          FAST   F1280W           NaN     NaN
# 463  MIR_FLATIMAGE-EXT          FAST   F1280W           NaN     NaN
# 464  MIR_FLATIMAGE-EXT          FAST   F1280W           NaN     NaN
# 465  MIR_FLATIMAGE-EXT          FAST   F1280W           NaN     NaN
# 466  MIR_FLATIMAGE-EXT          FAST   F1280W           NaN     NaN
# 467  MIR_FLATIMAGE-EXT          FAST   F1280W           NaN     NaN
# 468  MIR_FLATIMAGE-EXT          FAST   F1280W           NaN     NaN
# 469  MIR_FLATIMAGE-EXT          FAST   F1500W           NaN     NaN
# 470  MIR_FLATIMAGE-EXT          FAST   F1500W           NaN     NaN
# 471  MIR_FLATIMAGE-EXT          FAST   F1500W           NaN     NaN
# 472  MIR_FLATIMAGE-EXT          FAST   F1500W           NaN     NaN
# 473  MIR_FLATIMAGE-EXT          FAST   F1500W           NaN     NaN
# 474  MIR_FLATIMAGE-EXT          FAST   F1500W           NaN     NaN
# 475  MIR_FLATIMAGE-EXT          FAST   F1500W           NaN     NaN
# 476  MIR_FLATIMAGE-EXT          FAST   F1500W           NaN     NaN
# 477  MIR_FLATIMAGE-EXT          FAST   F1500W           NaN     NaN
# 478  MIR_FLATIMAGE-EXT          FAST   F1500W           NaN     NaN
# 479  MIR_FLATIMAGE-EXT          FAST   F1800W           NaN     NaN
# 480  MIR_FLATIMAGE-EXT          FAST   F1800W           NaN     NaN
# 481  MIR_FLATIMAGE-EXT          FAST   F1800W           NaN     NaN
# 482  MIR_FLATIMAGE-EXT          FAST   F1800W           NaN     NaN
# 483  MIR_FLATIMAGE-EXT          FAST   F1800W           NaN     NaN
# 484  MIR_FLATIMAGE-EXT          FAST   F1800W           NaN     NaN
# 485  MIR_FLATIMAGE-EXT          FAST   F1800W           NaN     NaN
# 486  MIR_FLATIMAGE-EXT          FAST   F1800W           NaN     NaN
# 487  MIR_FLATIMAGE-EXT          FAST   F1800W           NaN     NaN
# 488  MIR_FLATIMAGE-EXT          FAST   F1800W           NaN     NaN
# 489  MIR_FLATIMAGE-EXT          FAST   F2100W           NaN     NaN
# 490  MIR_FLATIMAGE-EXT          FAST   F2100W           NaN     NaN
# 491  MIR_FLATIMAGE-EXT          FAST   F2100W           NaN     NaN
# 492  MIR_FLATIMAGE-EXT          FAST   F2100W           NaN     NaN
# 493  MIR_FLATIMAGE-EXT          FAST   F2100W           NaN     NaN
# 494  MIR_FLATIMAGE-EXT          FAST   F2100W           NaN     NaN
# 495  MIR_FLATIMAGE-EXT          FAST   F2100W           NaN     NaN
# 496  MIR_FLATIMAGE-EXT          FAST   F2100W           NaN     NaN
# 497  MIR_FLATIMAGE-EXT          FAST   F2100W           NaN     NaN
# 498  MIR_FLATIMAGE-EXT          FAST   F2100W           NaN     NaN
# 499  MIR_FLATIMAGE-EXT          FAST   F2550W           NaN     NaN
# 500  MIR_FLATIMAGE-EXT          FAST   F2550W           NaN     NaN
# 501  MIR_FLATIMAGE-EXT          FAST   F2550W           NaN     NaN
# 502  MIR_FLATIMAGE-EXT          FAST   F2550W           NaN     NaN
# 503  MIR_FLATIMAGE-EXT          FAST   F2550W           NaN     NaN
# 504  MIR_FLATIMAGE-EXT          FAST   F2550W           NaN     NaN
# 505  MIR_FLATIMAGE-EXT          FAST   F2550W           NaN     NaN
# 506  MIR_FLATIMAGE-EXT          FAST   F2550W           NaN     NaN
# 507  MIR_FLATIMAGE-EXT          FAST   F2550W           NaN     NaN
# 508  MIR_FLATIMAGE-EXT          FAST   F2550W           NaN     NaN
# 509  MIR_FLATIMAGE-EXT          FAST  F2550WR           NaN     NaN
# 510  MIR_FLATIMAGE-EXT          FAST  F2550WR           NaN     NaN
# 511  MIR_FLATIMAGE-EXT          FAST  F2550WR           NaN     NaN
# 512  MIR_FLATIMAGE-EXT          FAST  F2550WR           NaN     NaN
# 513  MIR_FLATIMAGE-EXT          FAST  F2550WR           NaN     NaN
# 514  MIR_FLATIMAGE-EXT          FAST  F2550WR           NaN     NaN
# 515  MIR_FLATIMAGE-EXT          FAST  F2550WR           NaN     NaN
# 516  MIR_FLATIMAGE-EXT          FAST  F2550WR           NaN     NaN
# 517  MIR_FLATIMAGE-EXT          FAST  F2550WR           NaN     NaN
# 518  MIR_FLATIMAGE-EXT          FAST  F2550WR           NaN     NaN
# 519  MIR_FLATIMAGE-EXT          FAST    FLENS           NaN     NaN
# 520  MIR_FLATIMAGE-EXT          FAST    FLENS           NaN     NaN
# 521  MIR_FLATIMAGE-EXT          FAST    FLENS           NaN     NaN
# 522  MIR_FLATIMAGE-EXT          FAST    FLENS           NaN     NaN
# 523  MIR_FLATIMAGE-EXT          FAST    FLENS           NaN     NaN
# 524  MIR_FLATIMAGE-EXT          FAST    FLENS           NaN     NaN
# 525  MIR_FLATIMAGE-EXT          FAST    FLENS           NaN     NaN
# 526  MIR_FLATIMAGE-EXT          FAST    FLENS           NaN     NaN
# 527  MIR_FLATIMAGE-EXT          FAST    FLENS           NaN     NaN
# 528  MIR_FLATIMAGE-EXT          FAST    FLENS           NaN     NaN
# 529  MIR_FLATIMAGE-EXT          FAST   OPAQUE           NaN     NaN
# 530  MIR_FLATIMAGE-EXT          FAST   OPAQUE           NaN     NaN
# 531  MIR_FLATIMAGE-EXT          FAST   OPAQUE           NaN     NaN
# 532  MIR_FLATIMAGE-EXT          FAST   OPAQUE           NaN     NaN
# 533  MIR_FLATIMAGE-EXT          FAST   OPAQUE           NaN     NaN
# 534  MIR_FLATIMAGE-EXT          FAST   OPAQUE           NaN     NaN
# 535  MIR_FLATIMAGE-EXT          FAST   OPAQUE           NaN     NaN
# 536  MIR_FLATIMAGE-EXT          FAST   OPAQUE           NaN     NaN
# 537  MIR_FLATIMAGE-EXT          FAST   OPAQUE           NaN     NaN
# 538  MIR_FLATIMAGE-EXT          FAST   OPAQUE           NaN     NaN
# 539  MIR_FLATIMAGE-EXT          FAST      FND           NaN     NaN
# 540  MIR_FLATIMAGE-EXT          FAST      FND           NaN     NaN
# 541  MIR_FLATIMAGE-EXT          FAST      FND           NaN     NaN
# 542  MIR_FLATIMAGE-EXT          FAST      FND           NaN     NaN
# 543  MIR_FLATIMAGE-EXT          FAST      FND           NaN     NaN
# 544  MIR_FLATIMAGE-EXT          FAST      FND           NaN     NaN
# 545  MIR_FLATIMAGE-EXT          FAST      FND           NaN     NaN
# 546  MIR_FLATIMAGE-EXT          FAST      FND           NaN     NaN
# 547  MIR_FLATIMAGE-EXT          FAST      FND           NaN     NaN
# 548  MIR_FLATIMAGE-EXT          FAST      FND           NaN     NaN
# 549  MIR_FLATIMAGE-EXT          FAST   F1065C           NaN     NaN
# 550  MIR_FLATIMAGE-EXT          FAST   F1065C           NaN     NaN
# 551  MIR_FLATIMAGE-EXT          FAST   F1065C           NaN     NaN
# 552  MIR_FLATIMAGE-EXT          FAST   F1065C           NaN     NaN
# 553  MIR_FLATIMAGE-EXT          FAST   F1065C           NaN     NaN
# 554  MIR_FLATIMAGE-EXT          FAST   F1065C           NaN     NaN
# 555  MIR_FLATIMAGE-EXT          FAST   F1065C           NaN     NaN
# 556  MIR_FLATIMAGE-EXT          FAST   F1065C           NaN     NaN
# 557  MIR_FLATIMAGE-EXT          FAST   F1065C           NaN     NaN
# 558  MIR_FLATIMAGE-EXT          FAST   F1065C           NaN     NaN
# 559  MIR_FLATIMAGE-EXT          FAST   F1140C           NaN     NaN
# 560  MIR_FLATIMAGE-EXT          FAST   F1140C           NaN     NaN
# 561  MIR_FLATIMAGE-EXT          FAST   F1140C           NaN     NaN
# 562  MIR_FLATIMAGE-EXT          FAST   F1140C           NaN     NaN
# 563  MIR_FLATIMAGE-EXT          FAST   F1140C           NaN     NaN
# 564  MIR_FLATIMAGE-EXT          FAST   F1140C           NaN     NaN
# 565  MIR_FLATIMAGE-EXT          FAST   F1140C           NaN     NaN
# 566  MIR_FLATIMAGE-EXT          FAST   F1140C           NaN     NaN
# 567  MIR_FLATIMAGE-EXT          FAST   F1140C           NaN     NaN
# 568  MIR_FLATIMAGE-EXT          FAST   F1140C           NaN     NaN
# 569  MIR_FLATIMAGE-EXT          FAST   F1550C           NaN     NaN
# 570  MIR_FLATIMAGE-EXT          FAST   F1550C           NaN     NaN
# 571  MIR_FLATIMAGE-EXT          FAST   F1550C           NaN     NaN
# 572  MIR_FLATIMAGE-EXT          FAST   F1550C           NaN     NaN
# 573  MIR_FLATIMAGE-EXT          FAST   F1550C           NaN     NaN
# 574  MIR_FLATIMAGE-EXT          FAST   F1550C           NaN     NaN
# 575  MIR_FLATIMAGE-EXT          FAST   F1550C           NaN     NaN
# 576  MIR_FLATIMAGE-EXT          FAST   F1550C           NaN     NaN
# 577  MIR_FLATIMAGE-EXT          FAST   F1550C           NaN     NaN
# 578  MIR_FLATIMAGE-EXT          FAST   F1550C           NaN     NaN
# 579  MIR_FLATIMAGE-EXT          FAST   F2300C           NaN     NaN
# 580  MIR_FLATIMAGE-EXT          FAST   F2300C           NaN     NaN
# 581  MIR_FLATIMAGE-EXT          FAST   F2300C           NaN     NaN
# 582  MIR_FLATIMAGE-EXT          FAST   F2300C           NaN     NaN
# 583  MIR_FLATIMAGE-EXT          FAST   F2300C           NaN     NaN
# 584  MIR_FLATIMAGE-EXT          FAST   F2300C           NaN     NaN
# 585  MIR_FLATIMAGE-EXT          FAST   F2300C           NaN     NaN
# 586  MIR_FLATIMAGE-EXT          FAST   F2300C           NaN     NaN
# 587  MIR_FLATIMAGE-EXT          FAST   F2300C           NaN     NaN
# 588  MIR_FLATIMAGE-EXT          FAST   F2300C           NaN     NaN
# 589  MIR_FLATIMAGE-EXT          FAST    P750L           NaN     NaN
# 590  MIR_FLATIMAGE-EXT          FAST    P750L           NaN     NaN
# 591  MIR_FLATIMAGE-EXT          FAST    P750L           NaN     NaN
# 592  MIR_FLATIMAGE-EXT          FAST    P750L           NaN     NaN
# 593  MIR_FLATIMAGE-EXT          FAST    P750L           NaN     NaN
# 594  MIR_FLATIMAGE-EXT          FAST    P750L           NaN     NaN
# 595  MIR_FLATIMAGE-EXT          FAST    P750L           NaN     NaN
# 596  MIR_FLATIMAGE-EXT          FAST    P750L           NaN     NaN
# 597  MIR_FLATIMAGE-EXT          FAST    P750L           NaN     NaN
# 598  MIR_FLATIMAGE-EXT          FAST    P750L           NaN     NaN
# 599  MIR_FLATIMAGE-EXT          SLOW    F560W           NaN     NaN
# 600  MIR_FLATIMAGE-EXT          SLOW    F770W           NaN     NaN
# 601  MIR_FLATIMAGE-EXT          SLOW   F1000W           NaN     NaN
# 602  MIR_FLATIMAGE-EXT          SLOW   F1130W           NaN     NaN
# 603  MIR_FLATIMAGE-EXT          SLOW   F1280W           NaN     NaN
# 604  MIR_FLATIMAGE-EXT          SLOW   F1500W           NaN     NaN
# 605  MIR_FLATIMAGE-EXT          SLOW   F1800W           NaN     NaN
# 606  MIR_FLATIMAGE-EXT          SLOW   F2100W           NaN     NaN
# 607  MIR_FLATIMAGE-EXT          SLOW   F2550W           NaN     NaN
# 608  MIR_FLATIMAGE-EXT          SLOW  F2550WR           NaN     NaN
# 609  MIR_FLATIMAGE-EXT          SLOW    FLENS           NaN     NaN
# 610  MIR_FLATIMAGE-EXT          SLOW   OPAQUE           NaN     NaN
# 611  MIR_FLATIMAGE-EXT          SLOW      FND           NaN     NaN
# 612  MIR_FLATIMAGE-EXT          SLOW   F1065C           NaN     NaN
# 613  MIR_FLATIMAGE-EXT          SLOW   F1140C           NaN     NaN
# 614  MIR_FLATIMAGE-EXT          SLOW   F1550C           NaN     NaN
# 615  MIR_FLATIMAGE-EXT          SLOW   F2300C           NaN     NaN
# 616  MIR_FLATIMAGE-EXT          SLOW    P750L           NaN     NaN
# 617  MIR_LRS-FIXEDSLIT          FAST    P750L           NaN     NaN
# 618  MIR_LRS-FIXEDSLIT          SLOW    P750L           NaN     NaN
# 619  MIR_LRS-FIXEDSLIT    FASTGRPAVG    P750L           NaN     NaN
# 620   MIR_LRS-SLITLESS          FAST    P750L           NaN     NaN
# 621   MIR_LRS-SLITLESS    FASTGRPAVG    P750L           NaN     NaN
# 622            MIR_MRS          FAST      NaN         SHORT      12
# 623            MIR_MRS          FAST      NaN         SHORT      34
# 624            MIR_MRS          FAST      NaN  SHORT-MEDIUM      12
# 625            MIR_MRS          FAST      NaN  SHORT-MEDIUM      34
# 626            MIR_MRS          FAST      NaN    SHORT-LONG      12
# 627            MIR_MRS          FAST      NaN    SHORT-LONG      34
# 628            MIR_MRS          FAST      NaN  MEDIUM-SHORT      12
# 629            MIR_MRS          FAST      NaN  MEDIUM-SHORT      34
# 630            MIR_MRS          FAST      NaN        MEDIUM      12
# 631            MIR_MRS          FAST      NaN        MEDIUM      34
# 632            MIR_MRS          FAST      NaN   MEDIUM-LONG      12
# 633            MIR_MRS          FAST      NaN   MEDIUM-LONG      34
# 634            MIR_MRS          FAST      NaN    LONG-SHORT      12
# 635            MIR_MRS          FAST      NaN    LONG-SHORT      34
# 636            MIR_MRS          FAST      NaN   LONG-MEDIUM      12
# 637            MIR_MRS          FAST      NaN   LONG-MEDIUM      34
# 638            MIR_MRS          FAST      NaN          LONG      12
# 639            MIR_MRS          FAST      NaN          LONG      34
# 640            MIR_MRS          SLOW      NaN         SHORT      12
# 641            MIR_MRS          SLOW      NaN         SHORT      34
# 642            MIR_MRS          SLOW      NaN  SHORT-MEDIUM      12
# 643            MIR_MRS          SLOW      NaN  SHORT-MEDIUM      34
# 644            MIR_MRS          SLOW      NaN    SHORT-LONG      12
# 645            MIR_MRS          SLOW      NaN    SHORT-LONG      34
# 646            MIR_MRS          SLOW      NaN  MEDIUM-SHORT      12
# 647            MIR_MRS          SLOW      NaN  MEDIUM-SHORT      34
# 648            MIR_MRS          SLOW      NaN        MEDIUM      12
# 649            MIR_MRS          SLOW      NaN        MEDIUM      34
# 650            MIR_MRS          SLOW      NaN   MEDIUM-LONG      12
# 651            MIR_MRS          SLOW      NaN   MEDIUM-LONG      34
# 652            MIR_MRS          SLOW      NaN    LONG-SHORT      12
# 653            MIR_MRS          SLOW      NaN    LONG-SHORT      34
# 654            MIR_MRS          SLOW      NaN   LONG-MEDIUM      12
# 655            MIR_MRS          SLOW      NaN   LONG-MEDIUM      34
# 656            MIR_MRS          SLOW      NaN          LONG      12
# 657            MIR_MRS          SLOW      NaN          LONG      34
# 658            MIR_MRS    FASTGRPAVG      NaN         SHORT      12
# 659            MIR_MRS    FASTGRPAVG      NaN         SHORT      34
# 660            MIR_MRS    FASTGRPAVG      NaN  SHORT-MEDIUM      12
# 661            MIR_MRS    FASTGRPAVG      NaN  SHORT-MEDIUM      34
# 662            MIR_MRS    FASTGRPAVG      NaN    SHORT-LONG      12
# 663            MIR_MRS    FASTGRPAVG      NaN    SHORT-LONG      34
# 664            MIR_MRS    FASTGRPAVG      NaN  MEDIUM-SHORT      12
# 665            MIR_MRS    FASTGRPAVG      NaN  MEDIUM-SHORT      34
# 666            MIR_MRS    FASTGRPAVG      NaN        MEDIUM      12
# 667            MIR_MRS    FASTGRPAVG      NaN        MEDIUM      34
# 668            MIR_MRS    FASTGRPAVG      NaN   MEDIUM-LONG      12
# 669            MIR_MRS    FASTGRPAVG      NaN   MEDIUM-LONG      34
# 670            MIR_MRS    FASTGRPAVG      NaN    LONG-SHORT      12
# 671            MIR_MRS    FASTGRPAVG      NaN    LONG-SHORT      34
# 672            MIR_MRS    FASTGRPAVG      NaN   LONG-MEDIUM      12
# 673            MIR_MRS    FASTGRPAVG      NaN   LONG-MEDIUM      34
# 674            MIR_MRS    FASTGRPAVG      NaN          LONG      12
# ...
# 464     MIRIMAGE  SLITLESSPRISM
# 465     MIRIMAGE       MASK1065
# 466     MIRIMAGE       MASK1140
# 467     MIRIMAGE       MASK1550
# 468     MIRIMAGE       MASKLYOT
# 469     MIRIMAGE           FULL
# 470     MIRIMAGE      BRIGHTSKY
# 471     MIRIMAGE         SUB256
# 472     MIRIMAGE         SUB128
# 473     MIRIMAGE          SUB64
# 474     MIRIMAGE  SLITLESSPRISM
# 475     MIRIMAGE       MASK1065
# 476     MIRIMAGE       MASK1140
# 477     MIRIMAGE       MASK1550
# 478     MIRIMAGE       MASKLYOT
# 479     MIRIMAGE           FULL
# 480     MIRIMAGE      BRIGHTSKY
# 481     MIRIMAGE         SUB256
# 482     MIRIMAGE         SUB128
# 483     MIRIMAGE          SUB64
# 484     MIRIMAGE  SLITLESSPRISM
# 485     MIRIMAGE       MASK1065
# 486     MIRIMAGE       MASK1140
# 487     MIRIMAGE       MASK1550
# 488     MIRIMAGE       MASKLYOT
# 489     MIRIMAGE           FULL
# 490     MIRIMAGE      BRIGHTSKY
# 491     MIRIMAGE         SUB256
# 492     MIRIMAGE         SUB128
# 493     MIRIMAGE          SUB64
# 494     MIRIMAGE  SLITLESSPRISM
# 495     MIRIMAGE       MASK1065
# 496     MIRIMAGE       MASK1140
# 497     MIRIMAGE       MASK1550
# 498     MIRIMAGE       MASKLYOT
# 499     MIRIMAGE           FULL
# 500     MIRIMAGE      BRIGHTSKY
# 501     MIRIMAGE         SUB256
# 502     MIRIMAGE         SUB128
# 503     MIRIMAGE          SUB64
# 504     MIRIMAGE  SLITLESSPRISM
# 505     MIRIMAGE       MASK1065
# 506     MIRIMAGE       MASK1140
# 507     MIRIMAGE       MASK1550
# 508     MIRIMAGE       MASKLYOT
# 509     MIRIMAGE           FULL
# 510     MIRIMAGE      BRIGHTSKY
# 511     MIRIMAGE         SUB256
# 512     MIRIMAGE         SUB128
# 513     MIRIMAGE          SUB64
# 514     MIRIMAGE  SLITLESSPRISM
# 515     MIRIMAGE       MASK1065
# 516     MIRIMAGE       MASK1140
# 517     MIRIMAGE       MASK1550
# 518     MIRIMAGE       MASKLYOT
# 519     MIRIMAGE           FULL
# 520     MIRIMAGE      BRIGHTSKY
# 521     MIRIMAGE         SUB256
# 522     MIRIMAGE         SUB128
# 523     MIRIMAGE          SUB64
# 524     MIRIMAGE  SLITLESSPRISM
# 525     MIRIMAGE       MASK1065
# 526     MIRIMAGE       MASK1140
# 527     MIRIMAGE       MASK1550
# 528     MIRIMAGE       MASKLYOT
# 529     MIRIMAGE           FULL
# 530     MIRIMAGE      BRIGHTSKY
# 531     MIRIMAGE         SUB256
# 532     MIRIMAGE         SUB128
# 533     MIRIMAGE          SUB64
# 534     MIRIMAGE  SLITLESSPRISM
# 535     MIRIMAGE       MASK1065
# 536     MIRIMAGE       MASK1140
# 537     MIRIMAGE       MASK1550
# 538     MIRIMAGE       MASKLYOT
# 539     MIRIMAGE           FULL
# 540     MIRIMAGE      BRIGHTSKY
# 541     MIRIMAGE         SUB256
# 542     MIRIMAGE         SUB128
# 543     MIRIMAGE          SUB64
# 544     MIRIMAGE  SLITLESSPRISM
# 545     MIRIMAGE       MASK1065
# 546     MIRIMAGE       MASK1140
# 547     MIRIMAGE       MASK1550
# 548     MIRIMAGE       MASKLYOT
# 549     MIRIMAGE           FULL
# 550     MIRIMAGE      BRIGHTSKY
# 551     MIRIMAGE         SUB256
# 552     MIRIMAGE         SUB128
# 553     MIRIMAGE          SUB64
# 554     MIRIMAGE  SLITLESSPRISM
# 555     MIRIMAGE       MASK1065
# 556     MIRIMAGE       MASK1140
# 557     MIRIMAGE       MASK1550
# 558     MIRIMAGE       MASKLYOT
# 559     MIRIMAGE           FULL
# 560     MIRIMAGE      BRIGHTSKY
# 561     MIRIMAGE         SUB256
# 562     MIRIMAGE         SUB128
# 563     MIRIMAGE          SUB64
# 564     MIRIMAGE  SLITLESSPRISM
# 565     MIRIMAGE       MASK1065
# 566     MIRIMAGE       MASK1140
# 567     MIRIMAGE       MASK1550
# 568     MIRIMAGE       MASKLYOT
# 569     MIRIMAGE           FULL
# 570     MIRIMAGE      BRIGHTSKY
# 571     MIRIMAGE         SUB256
# 572     MIRIMAGE         SUB128
# 573     MIRIMAGE          SUB64
# 574     MIRIMAGE  SLITLESSPRISM
# 575     MIRIMAGE       MASK1065
# 576     MIRIMAGE       MASK1140
# 577     MIRIMAGE       MASK1550
# 578     MIRIMAGE       MASKLYOT
# 579     MIRIMAGE           FULL
# 580     MIRIMAGE      BRIGHTSKY
# 581     MIRIMAGE         SUB256
# 582     MIRIMAGE         SUB128
# 583     MIRIMAGE          SUB64
# 584     MIRIMAGE  SLITLESSPRISM
# 585     MIRIMAGE       MASK1065
# 586     MIRIMAGE       MASK1140
# 587     MIRIMAGE       MASK1550
# 588     MIRIMAGE       MASKLYOT
# 589     MIRIMAGE           FULL
# 590     MIRIMAGE      BRIGHTSKY
# 591     MIRIMAGE         SUB256
# 592     MIRIMAGE         SUB128
# 593     MIRIMAGE          SUB64
# 594     MIRIMAGE  SLITLESSPRISM
# 595     MIRIMAGE       MASK1065
# 596     MIRIMAGE       MASK1140
# 597     MIRIMAGE       MASK1550
# 598     MIRIMAGE       MASKLYOT
# 599     MIRIMAGE           FULL
# 600     MIRIMAGE           FULL
# 601     MIRIMAGE           FULL
# 602     MIRIMAGE           FULL
# 603     MIRIMAGE           FULL
# 604     MIRIMAGE           FULL
# 605     MIRIMAGE           FULL
# 606     MIRIMAGE           FULL
# 607     MIRIMAGE           FULL
# 608     MIRIMAGE           FULL
# 609     MIRIMAGE           FULL
# 610     MIRIMAGE           FULL
# 611     MIRIMAGE           FULL
# 612     MIRIMAGE           FULL
# 613     MIRIMAGE           FULL
# 614     MIRIMAGE           FULL
# 615     MIRIMAGE           FULL
# 616     MIRIMAGE           FULL
# 617     MIRIMAGE           FULL
# 618     MIRIMAGE           FULL
# 619     MIRIMAGE           FULL
# 620     MIRIMAGE  SLITLESSPRISM
# 621     MIRIMAGE  SLITLESSPRISM
# 622  MIRIFUSHORT           FULL
# 623   MIRIFULONG           FULL
# 624  MIRIFUSHORT           FULL
# 625   MIRIFULONG           FULL
# 626  MIRIFUSHORT           FULL
# 627   MIRIFULONG           FULL
# 628  MIRIFUSHORT           FULL
# 629   MIRIFULONG           FULL
# 630  MIRIFUSHORT           FULL
# 631   MIRIFULONG           FULL
# 632  MIRIFUSHORT           FULL
# 633   MIRIFULONG           FULL
# 634  MIRIFUSHORT           FULL
# 635   MIRIFULONG           FULL
# 636  MIRIFUSHORT           FULL
# 637   MIRIFULONG           FULL
# 638  MIRIFUSHORT           FULL
# 639   MIRIFULONG           FULL
# 640  MIRIFUSHORT           FULL
# 641   MIRIFULONG           FULL
# 642  MIRIFUSHORT           FULL
# 643   MIRIFULONG           FULL
# 644  MIRIFUSHORT           FULL
# 645   MIRIFULONG           FULL
# 646  MIRIFUSHORT           FULL
# 647   MIRIFULONG           FULL
# 648  MIRIFUSHORT           FULL
# 649   MIRIFULONG           FULL
# 650  MIRIFUSHORT           FULL
# 651   MIRIFULONG           FULL
# 652  MIRIFUSHORT           FULL
# 653   MIRIFULONG           FULL
# 654  MIRIFUSHORT           FULL
# 655   MIRIFULONG           FULL
# 656  MIRIFUSHORT           FULL
# 657   MIRIFULONG           FULL
# 658  MIRIFUSHORT           FULL
# 659   MIRIFULONG           FULL
# 660  MIRIFUSHORT           FULL
# 661   MIRIFULONG           FULL
# 662  MIRIFUSHORT           FULL
# 663   MIRIFULONG           FULL
# 664  MIRIFUSHORT           FULL
# 665   MIRIFULONG           FULL
# 666  MIRIFUSHORT           FULL
# 667   MIRIFULONG           FULL
# 668  MIRIFUSHORT           FULL
# 669   MIRIFULONG           FULL
# 670  MIRIFUSHORT           FULL
# 671   MIRIFULONG           FULL
# 672  MIRIFUSHORT           FULL
# 673   MIRIFULONG           FULL
# 674  MIRIFUSHORT           FULL
# 675   MIRIFULONG           FULL
# 676  MIRIFUSHORT           FULL
# 677   MIRIFULONG           FULL
# 678  MIRIFUSHORT           FULL
# 679   MIRIFULONG           FULL
# 680  MIRIFUSHORT           FULL
# 681   MIRIFULONG           FULL
# 682  MIRIFUSHORT           FULL
# 683   MIRIFULONG           FULL
# 684  MIRIFUSHORT           FULL
# 685   MIRIFULONG           FULL
# 686  MIRIFUSHORT           FULL
# 687   MIRIFULONG           FULL
# 688  MIRIFUSHORT           FULL
# 689   MIRIFULONG           FULL
# 690  MIRIFUSHORT           FULL
# 691   MIRIFULONG           FULL
# 692  MIRIFUSHORT           FULL
# 693   MIRIFULONG           FULL
# 694  MIRIFUSHORT           FULL
# 695   MIRIFULONG           FULL
# 696  MIRIFUSHORT           FULL
# 697   MIRIFULONG           FULL
# 698  MIRIFUSHORT           FULL
# 699   MIRIFULONG           FULL
# 700  MIRIFUSHORT           FULL
# 701   MIRIFULONG           FULL
# 702  MIRIFUSHORT           FULL
# 703   MIRIFULONG           FULL
# 704  MIRIFUSHORT           FULL
# 705   MIRIFULONG           FULL
# 706  MIRIFUSHORT           FULL
# 707   MIRIFULONG           FULL
# 708  MIRIFUSHORT           FULL
# 709   MIRIFULONG           FULL
# 710  MIRIFUSHORT           FULL
# 711   MIRIFULONG           FULL
# 712     MIRIMAGE       MASK1065
# 713     MIRIMAGE       MASK1065
# 714     MIRIMAGE       MASK1065
# 715     MIRIMAGE       MASK1065
# 716     MIRIMAGE       MASK1065
# 717     MIRIMAGE       MASK1140
# 718     MIRIMAGE       MASK1140
# 719     MIRIMAGE       MASK1140
# 720     MIRIMAGE       MASK1140
# 721     MIRIMAGE       MASK1140
# 722     MIRIMAGE       MASK1140
# 723     MIRIMAGE       MASK1550
# 724     MIRIMAGE       MASK1550
# 725     MIRIMAGE       MASK1550
# 726     MIRIMAGE       MASK1550
# 727     MIRIMAGE       MASK1550
# 728     MIRIMAGE       MASK1550
# 729     MIRIMAGE       MASK1550
# 730     MIRIMAGE       MASKLYOT
# 731     MIRIMAGE       MASKLYOT
# 732     MIRIMAGE       MASKLYOT
# 733     MIRIMAGE       MASKLYOT
# 734     MIRIMAGE       MASKLYOT
# 735     MIRIMAGE       MASKLYOT
# 736     MIRIMAGE       MASKLYOT
# 737     MIRIMAGE       MASKLYOT
# 738     MIRIMAGE       MASKLYOT
# 739     MIRIMAGE       MASKLYOT
# 740     MIRIMAGE       MASK1065
# 741     MIRIMAGE       MASK1140
# 742     MIRIMAGE       MASK1550
# 743     MIRIMAGE       MASK1065
# 744     MIRIMAGE       MASK1140
# 745     MIRIMAGE       MASK1550
# 746     MIRIMAGE           FULL
# 747     MIRIMAGE  SLITLESSPRISM
# 748     MIRIMAGE       MASK1065
# 749     MIRIMAGE       MASK1140
# 750     MIRIMAGE       MASK1550
# 751     MIRIMAGE       MASKLYOT
# 752     MIRIMAGE           FULL
# 753     MIRIMAGE  SLITLESSPRISM
# 754     MIRIMAGE       MASK1065
# 755     MIRIMAGE       MASK1140
# 756     MIRIMAGE       MASK1550
# 757     MIRIMAGE       MASKLYOT
# 758     MIRIMAGE           FULL
# 759     MIRIMAGE  SLITLESSPRISM
# 760     MIRIMAGE       MASK1065
# 761     MIRIMAGE       MASK1140
# 762     MIRIMAGE       MASK1550
# 763     MIRIMAGE       MASKLYOT
# 764     MIRIMAGE           FULL
# 765     MIRIMAGE  SLITLESSPRISM
# 766     MIRIMAGE       MASK1065
# 767     MIRIMAGE       MASK1140
# 768     MIRIMAGE       MASK1550
# 769     MIRIMAGE       MASKLYOT
# 770     MIRIMAGE           FULL
# 771     MIRIMAGE  SLITLESSPRISM
# 772     MIRIMAGE       MASK1065
# 773     MIRIMAGE       MASK1140
# 774     MIRIMAGE       MASK1550
# 775     MIRIMAGE       MASKLYOT
# 776     MIRIMAGE           FULL
# 777     MIRIMAGE  SLITLESSPRISM
# 778     MIRIMAGE       MASK1065
# 779     MIRIMAGE       MASK1140
# 780     MIRIMAGE       MASK1550
# 781     MIRIMAGE       MASKLYOT
# 782     MIRIMAGE           FULL
# 783     MIRIMAGE  SLITLESSPRISM
# 784     MIRIMAGE       MASK1065
# 785     MIRIMAGE       MASK1140
# 786     MIRIMAGE       MASK1550
# 787     MIRIMAGE       MASKLYOT
# 788     MIRIMAGE           FULL
# 789     MIRIMAGE  SLITLESSPRISM
# 790     MIRIMAGE       MASK1065
# 791     MIRIMAGE       MASK1140
# 792     MIRIMAGE       MASK1550
# 793     MIRIMAGE       MASKLYOT
# 794     MIRIMAGE           FULL
# 795     MIRIMAGE  SLITLESSPRISM
# 796     MIRIMAGE       MASK1065
# 797     MIRIMAGE       MASK1140
# 798     MIRIMAGE       MASK1550
# 799     MIRIMAGE       MASKLYOT
# 800     MIRIMAGE           FULL
# 801     MIRIMAGE  SLITLESSPRISM
# 802     MIRIMAGE       MASK1065
# 803     MIRIMAGE       MASK1140
# 804     MIRIMAGE       MASK1550
# 805     MIRIMAGE       MASKLYOT
# 806     MIRIMAGE           FULL
# 807     MIRIMAGE  SLITLESSPRISM
# 808     MIRIMAGE       MASK1065
# 809     MIRIMAGE       MASK1140
# 810     MIRIMAGE       MASK1550
# 811     MIRIMAGE       MASKLYOT
# 812     MIRIMAGE           FULL
# 813     MIRIMAGE  SLITLESSPRISM
# 814     MIRIMAGE       MASK1065
# 815     MIRIMAGE       MASK1140
# 816     MIRIMAGE       MASK1550
# 817     MIRIMAGE       MASKLYOT
# 818     MIRIMAGE           FULL
# 819     MIRIMAGE  SLITLESSPRISM
# 820     MIRIMAGE       MASK1065
# 821     MIRIMAGE       MASK1140
# 822     MIRIMAGE       MASK1550
# 823     MIRIMAGE       MASKLYOT
# 824     MIRIMAGE           FULL
# 825     MIRIMAGE  SLITLESSPRISM
# 826     MIRIMAGE       MASK1065
# 827     MIRIMAGE       MASK1140
# 828     MIRIMAGE       MASK1550
# 829     MIRIMAGE       MASKLYOT
# 830     MIRIMAGE           FULL
# 831     MIRIMAGE  SLITLESSPRISM
# 832     MIRIMAGE       MASK1065
# 833     MIRIMAGE       MASK1140
# 834     MIRIMAGE       MASK1550
# 835     MIRIMAGE       MASKLYOT
# 836     MIRIMAGE           FULL
# 837     MIRIMAGE  SLITLESSPRISM
# 838     MIRIMAGE       MASK1065
# 839     MIRIMAGE       MASK1140
# 840     MIRIMAGE       MASK1550
# 841     MIRIMAGE       MASKLYOT
# 842     MIRIMAGE           FULL
# 843     MIRIMAGE  SLITLESSPRISM
# 844     MIRIMAGE       MASK1065
# 845     MIRIMAGE       MASK1140
# 846     MIRIMAGE       MASK1550
# 847     MIRIMAGE       MASKLYOT
# 848     MIRIMAGE           FULL
# 849     MIRIMAGE  SLITLESSPRISM
# 850     MIRIMAGE       MASK1065
# 851     MIRIMAGE       MASK1140
# 852     MIRIMAGE       MASK1550
# 853     MIRIMAGE       MASKLYOT
# 854     MIRIMAGE           FULL
# 855     MIRIMAGE  SLITLESSPRISM
# 856     MIRIMAGE       MASK1065
# 857     MIRIMAGE       MASK1140
# 858     MIRIMAGE       MASK1550
# 859     MIRIMAGE       MASKLYOT
# 860     MIRIMAGE           FULL
# 861     MIRIMAGE  SLITLESSPRISM
# 862     MIRIMAGE       MASK1065
# 863     MIRIMAGE       MASK1140
# 864     MIRIMAGE       MASK1550
# 865     MIRIMAGE       MASKLYOT
# 866     MIRIMAGE           FULL
# 867     MIRIMAGE  SLITLESSPRISM
# 868     MIRIMAGE       MASK1065
# 869     MIRIMAGE       MASK1140
# 870     MIRIMAGE       MASK1550
# 871     MIRIMAGE       MASKLYOT
# 872     MIRIMAGE           FULL
# 873     MIRIMAGE  SLITLESSPRISM
# 874     MIRIMAGE       MASK1065
# 875     MIRIMAGE       MASK1140
# 876     MIRIMAGE       MASK1550
# 877     MIRIMAGE       MASKLYOT
# 878     MIRIMAGE           FULL
# 879     MIRIMAGE  SLITLESSPRISM
# 880     MIRIMAGE       MASK1065
# 881     MIRIMAGE       MASK1140
# 882     MIRIMAGE       MASK1550
# 883     MIRIMAGE       MASKLYOT
# 884     MIRIMAGE           FULL
# 885     MIRIMAGE  SLITLESSPRISM
# 886     MIRIMAGE       MASK1065
# 887     MIRIMAGE       MASK1140
# 888     MIRIMAGE       MASK1550
# 889     MIRIMAGE       MASKLYOT
# 890     MIRIMAGE           FULL
# 891     MIRIMAGE  SLITLESSPRISM
# 892     MIRIMAGE           FULL
# 893     MIRIMAGE  SLITLESSPRISM
# 894     MIRIMAGE           FULL
# 895     MIRIMAGE  SLITLESSPRISM
# 896     MIRIMAGE           FULL
# 897     MIRIMAGE  SLITLESSPRISM
# 898     MIRIMAGE           FULL
# 899     MIRIMAGE      BRIGHTSKY
# 900     MIRIMAGE         SUB256
# 901     MIRIMAGE         SUB128
# 902     MIRIMAGE          SUB64
# 903     MIRIMAGE  SLITLESSPRISM
# 904     MIRIMAGE       MASK1065
# 905     MIRIMAGE       MASK1140
# 906     MIRIMAGE       MASK1550
# 907     MIRIMAGE       MASKLYOT
# 908     MIRIMAGE           FULL
# 909     MIRIMAGE      BRIGHTSKY
# 910     MIRIMAGE         SUB256
# 911     MIRIMAGE         SUB128
# 912     MIRIMAGE          SUB64
# 913     MIRIMAGE  SLITLESSPRISM
# 914     MIRIMAGE       MASK1065
# 915     MIRIMAGE       MASK1140
# 916     MIRIMAGE       MASK1550
# 917     MIRIMAGE       MASKLYOT
# 918     MIRIMAGE           FULL
# 919     MIRIMAGE      BRIGHTSKY
# 920     MIRIMAGE         SUB256
# 921     MIRIMAGE         SUB128
# 922     MIRIMAGE          SUB64
# 923     MIRIMAGE  SLITLESSPRISM
# 924     MIRIMAGE       MASK1065
# 925     MIRIMAGE       MASK1140
# 926     MIRIMAGE       MASK1550
# 927     MIRIMAGE       MASKLYOT
# 928  MIRIFUSHORT           FULL
# 929   MIRIFULONG           FULL
# 930  MIRIFUSHORT           FULL
# 931   MIRIFULONG           FULL
# 932  MIRIFUSHORT           FULL
# 933   MIRIFULONG           FULL

# %% [markdown]
# # Check CRDS

# %%
import crds

# %%
for i in df.index:
    e = df['Exposure Type'][i]
    
    if 'MRS' in e:
        r = df['Readout Mode'][i]
        b = df['Band'][i]
        c = df['Channel'][i]
        d = df['Detector'][i]
        s = df['SubArray'][i]
        
        params = {'INSTRUME': 'MIRI',
                 'EXP_TYPE': e,
                 'READPATT': r,
                 'BAND': b,
                 'CHANNEL': c,
                 'DETECTOR': d,
                 'SUBARRAY': s,
                 'DATE-OBS': '2021-02-08',
                 'TIME-OBS': '0:00:00'}
    else:
        r = df['Readout Mode'][i]
        f = df['Filter'][i]
        s = df['SubArray'][i]
    
        params = {'INSTRUME': 'MIRI',
                 'EXP_TYPE': e,
                 'READPATT': r,
                 'FILTER': f,
                 'SUBARRAY': s,
                 'Detector': 'MIRIMAGE',
                 'DATE-OBS': '2021-02-08',
                 'TIME-OBS': '0:00:00'}

    result = crds.getrecommendations(parameters=params)
    
    pr = False
    for key, val in result.items():
        #print('{}: {}'.format(key, val))
        if 'No match found' in val:
            pr = True
    
    if pr == True:
        print('-------------------------------------')
        print('Configuration:')
        for key, val in params.items():
            print('{}: {}'.format(key, val))

        print('\n')

        print('Result: ')
        for key, val in result.items():
            if 'No match found' in val:
                print('{}: {}'.format(key, val))
        print('-------------------------------------')

        print('\n')
# Out:
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: FLENS
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: FLENS
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: FLENS
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: FLENS
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: FLENS
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: OPAQUE
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: OPAQUE
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: OPAQUE
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: OPAQUE
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: OPAQUE
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F1065C
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F1065C
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F1065C
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F1065C
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F1065C
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F1140C
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F1140C
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F1140C
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F1140C
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F1140C
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F1550C
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F1550C
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F1550C
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F1550C
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F1550C
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F2300C
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F2300C
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F2300C
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F2300C
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: F2300C
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: P750L
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: P750L
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: P750L
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FAST
# FILTER: P750L
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F560W
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F560W
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F560W
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F560W
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F770W
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F770W
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F770W
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F770W
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1000W
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1000W
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1000W
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1000W
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1130W
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1130W
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1130W
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1130W
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1280W
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1280W
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1280W
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1280W
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1500W
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1500W
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1500W
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1500W
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1800W
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1800W
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1800W
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1800W
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F2100W
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F2100W
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F2100W
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F2100W
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F2550W
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F2550W
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F2550W
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F2550W
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: FLENS
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: FLENS
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: FLENS
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: FLENS
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: FLENS
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: OPAQUE
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: OPAQUE
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: OPAQUE
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: OPAQUE
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: OPAQUE
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: FND
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: FND
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: FND
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: FND
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1065C
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1065C
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1065C
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1065C
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1065C
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1140C
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1140C
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1140C
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1140C
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1140C
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1550C
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1550C
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1550C
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1550C
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F1550C
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F2300C
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F2300C
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F2300C
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F2300C
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: F2300C
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: P750L
# SUBARRAY: BRIGHTSKY
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: P750L
# SUBARRAY: SUB256
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: P750L
# SUBARRAY: SUB128
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: P750L
# SUBARRAY: SUB64
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# readnoise: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_IMAGE
# READPATT: FASTGRPAVG
# FILTER: P750L
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_LRS-SLITLESS
# READPATT: FASTGRPAVG
# FILTER: P750L
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: SHORT-MEDIUM
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: SHORT-MEDIUM
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: SHORT-LONG
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: SHORT-LONG
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: MEDIUM-SHORT
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: MEDIUM-SHORT
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: MEDIUM-LONG
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: MEDIUM-LONG
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: LONG-SHORT
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: LONG-SHORT
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: LONG-MEDIUM
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: LONG-MEDIUM
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: SHORT-MEDIUM
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: SHORT-MEDIUM
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: SHORT-LONG
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: SHORT-LONG
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: MEDIUM-SHORT
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: MEDIUM-SHORT
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: MEDIUM-LONG
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: MEDIUM-LONG
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: LONG-SHORT
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: LONG-SHORT
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: LONG-MEDIUM
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: LONG-MEDIUM
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FASTGRPAVG
# BAND: SHORT-MEDIUM
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FASTGRPAVG
# BAND: SHORT-MEDIUM
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FASTGRPAVG
# BAND: SHORT-LONG
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FASTGRPAVG
# BAND: SHORT-LONG
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FASTGRPAVG
# BAND: MEDIUM-SHORT
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FASTGRPAVG
# BAND: MEDIUM-SHORT
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FASTGRPAVG
# BAND: MEDIUM-LONG
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FASTGRPAVG
# BAND: MEDIUM-LONG
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FASTGRPAVG
# BAND: LONG-SHORT
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FASTGRPAVG
# BAND: LONG-SHORT
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FASTGRPAVG
# BAND: LONG-MEDIUM
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# ...
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: MEDIUM-SHORT
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: MEDIUM-SHORT
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: MEDIUM-LONG
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: MEDIUM-LONG
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: LONG-SHORT
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: LONG-SHORT
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: LONG-MEDIUM
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: FAST
# BAND: LONG-MEDIUM
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: SHORT-MEDIUM
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: SHORT-MEDIUM
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: SHORT-LONG
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: SHORT-LONG
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: MEDIUM-SHORT
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: MEDIUM-SHORT
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: MEDIUM-LONG
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: MEDIUM-LONG
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: LONG-SHORT
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: LONG-SHORT
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: LONG-MEDIUM
# CHANNEL: 12
# DETECTOR: MIRIFUSHORT
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# straymask: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_MRS
# READPATT: SLOW
# BAND: LONG-MEDIUM
# CHANNEL: 34
# DETECTOR: MIRIFULONG
# SUBARRAY: FULL
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# distortion: NOT FOUND No match found.
# specwcs: NOT FOUND No match found.
# flat: NOT FOUND No match found.
# fringe: NOT FOUND No match found.
# regions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_CORONCAL
# READPATT: FAST
# FILTER: F1065C
# SUBARRAY: MASK1140
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_CORONCAL
# READPATT: FAST
# FILTER: F1065C
# SUBARRAY: MASK1550
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_CORONCAL
# READPATT: FAST
# FILTER: F1140C
# SUBARRAY: MASK1550
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_CORONCAL
# READPATT: FAST
# FILTER: F1065C
# SUBARRAY: MASKLYOT
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_CORONCAL
# READPATT: FAST
# FILTER: F1140C
# SUBARRAY: MASKLYOT
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_CORONCAL
# READPATT: FAST
# FILTER: F1550C
# SUBARRAY: MASKLYOT
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# flat: NOT FOUND No match found.
# -------------------------------------
# CRDS - WARNING -  Failed determining reftypes for {'DATE-OBS': '2021-02-08',
#  'DETECTOR': 'MIRIMAGE',
#  'EXP_TYPE': 'MIR_TACONFIRM',
#  'FILTER': 'F560W',
#  'INSTRUME': 'MIRI',
#  'READPATT': 'FAST',
#  'SUBARRAY': 'FULL',
#  'TIME-OBS': '0:00:00'} : "Failed determining required pipeline .cfgs for EXP_TYPE 'MIR_TACONFIRM' : 'MIR_TACONFIRM'"
# CRDS - WARNING -  Failed determining reftypes for {'DATE-OBS': '2021-02-08',
#  'DETECTOR': 'MIRIMAGE',
#  'EXP_TYPE': 'MIR_TACONFIRM',
#  'FILTER': 'F560W',
#  'INSTRUME': 'MIRI',
#  'READPATT': 'FAST',
#  'SUBARRAY': 'SLITLESSPRISM',
#  'TIME-OBS': '0:00:00'} : "Failed determining required pipeline .cfgs for EXP_TYPE 'MIR_TACONFIRM' : 'MIR_TACONFIRM'"
# CRDS - WARNING -  Failed determining reftypes for {'DATE-OBS': '2021-02-08',
#  'DETECTOR': 'MIRIMAGE',
#  'EXP_TYPE': 'MIR_TACONFIRM',
#  'FILTER': 'F1000W',
#  'INSTRUME': 'MIRI',
#  'READPATT': 'FAST',
#  'SUBARRAY': 'FULL',
#  'TIME-OBS': '0:00:00'} : "Failed determining required pipeline .cfgs for EXP_TYPE 'MIR_TACONFIRM' : 'MIR_TACONFIRM'"
# CRDS - WARNING -  Failed determining reftypes for {'DATE-OBS': '2021-02-08',
#  'DETECTOR': 'MIRIMAGE',
#  'EXP_TYPE': 'MIR_TACONFIRM',
#  'FILTER': 'F1000W',
#  'INSTRUME': 'MIRI',
#  'READPATT': 'FAST',
#  'SUBARRAY': 'SLITLESSPRISM',
#  'TIME-OBS': '0:00:00'} : "Failed determining required pipeline .cfgs for EXP_TYPE 'MIR_TACONFIRM' : 'MIR_TACONFIRM'"
# CRDS - WARNING -  Failed determining reftypes for {'DATE-OBS': '2021-02-08',
#  'DETECTOR': 'MIRIMAGE',
#  'EXP_TYPE': 'MIR_TACONFIRM',
#  'FILTER': 'F1500W',
#  'INSTRUME': 'MIRI',
#  'READPATT': 'FAST',
#  'SUBARRAY': 'FULL',
#  'TIME-OBS': '0:00:00'} : "Failed determining required pipeline .cfgs for EXP_TYPE 'MIR_TACONFIRM' : 'MIR_TACONFIRM'"
# CRDS - WARNING -  Failed determining reftypes for {'DATE-OBS': '2021-02-08',
#  'DETECTOR': 'MIRIMAGE',
#  'EXP_TYPE': 'MIR_TACONFIRM',
#  'FILTER': 'F1500W',
#  'INSTRUME': 'MIRI',
#  'READPATT': 'FAST',
#  'SUBARRAY': 'SLITLESSPRISM',
#  'TIME-OBS': '0:00:00'} : "Failed determining required pipeline .cfgs for EXP_TYPE 'MIR_TACONFIRM' : 'MIR_TACONFIRM'"
# CRDS - WARNING -  Failed determining reftypes for {'DATE-OBS': '2021-02-08',
#  'DETECTOR': 'MIRIMAGE',
#  'EXP_TYPE': 'MIR_TACONFIRM',
#  'FILTER': 'FND',
#  'INSTRUME': 'MIRI',
#  'READPATT': 'FAST',
#  'SUBARRAY': 'FULL',
#  'TIME-OBS': '0:00:00'} : "Failed determining required pipeline .cfgs for EXP_TYPE 'MIR_TACONFIRM' : 'MIR_TACONFIRM'"
# CRDS - WARNING -  Failed determining reftypes for {'DATE-OBS': '2021-02-08',
#  'DETECTOR': 'MIRIMAGE',
#  'EXP_TYPE': 'MIR_TACONFIRM',
#  'FILTER': 'FND',
#  'INSTRUME': 'MIRI',
#  'READPATT': 'FAST',
#  'SUBARRAY': 'SLITLESSPRISM',
#  'TIME-OBS': '0:00:00'} : "Failed determining required pipeline .cfgs for EXP_TYPE 'MIR_TACONFIRM' : 'MIR_TACONFIRM'"
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_TACONFIRM
# READPATT: FAST
# FILTER: F560W
# SUBARRAY: FULL
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# psfmask: NOT FOUND No match found.
# wcsregions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_TACONFIRM
# READPATT: FAST
# FILTER: F560W
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# psfmask: NOT FOUND No match found.
# wcsregions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_TACONFIRM
# READPATT: FAST
# FILTER: F1000W
# SUBARRAY: FULL
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# psfmask: NOT FOUND No match found.
# wcsregions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_TACONFIRM
# READPATT: FAST
# FILTER: F1000W
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# psfmask: NOT FOUND No match found.
# wcsregions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_TACONFIRM
# READPATT: FAST
# FILTER: F1500W
# SUBARRAY: FULL
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# psfmask: NOT FOUND No match found.
# wcsregions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_TACONFIRM
# READPATT: FAST
# FILTER: F1500W
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# psfmask: NOT FOUND No match found.
# wcsregions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_TACONFIRM
# READPATT: FAST
# FILTER: FND
# SUBARRAY: FULL
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# psfmask: NOT FOUND No match found.
# wcsregions: NOT FOUND No match found.
# -------------------------------------
#
#
# -------------------------------------
# Configuration:
# INSTRUME: MIRI
# EXP_TYPE: MIR_TACONFIRM
# READPATT: FAST
# FILTER: FND
# SUBARRAY: SLITLESSPRISM
# Detector: MIRIMAGE
# DATE-OBS: 2021-02-08
# TIME-OBS: 0:00:00
#
#
# Result:
# psfmask: NOT FOUND No match found.
# wcsregions: NOT FOUND No match found.
# -------------------------------------
